# %%
import os
import math
import random 
import pandas as pd
import numpy as np
import datetime as dt
from pandas_datareader import data as pdr
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
from Util_def import *
from Util_model import *
from pypfopt import (
    EfficientFrontier,
    risk_models,
    expected_returns,
    objective_functions,
)

import warnings
warnings.filterwarnings('ignore')
# Out:
# Devices:  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU details:  {'device_name': 'METAL'}

# %%
stock_list = pd.read_excel('US_list.xlsx', sheet_name='nasdaq_nyse_mega')
stock_list = stock_list['SYMBOL'].tolist()

# 5 years data
startDate = dt.datetime(2010, 1, 1)
endDate = dt.datetime(2025, 7, 28)

start_rebalance_year = 2020  # startDate.year + 3

data = getData(stock_list, startDate, endDate)
data.fillna(method='ffill', inplace=True)
data.fillna(method='bfill', inplace=True)
print(data.info())
avg_days = avg_days_per_month(data)

print("=" * 50)
print("Min Date:", data.index.min())
print("Max Date:", data.index.max())
print("Start Rebalance Year:", start_rebalance_year)
print(f"Average number of trading days per month: {avg_days}", "days")
print("=" * 50)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  59 of 59 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3914 entries, 2010-01-04 to 2025-07-25
# Data columns (total 59 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3914 non-null   float64
#  1   AMD     3914 non-null   float64
#  2   AMZN    3914 non-null   float64
#  3   ASML    3914 non-null   float64
#  4   AVGO    3914 non-null   float64
#  5   AZN     3914 non-null   float64
#  6   COST    3914 non-null   float64
#  7   CSCO    3914 non-null   float64
#  8   GOOG    3914 non-null   float64
#  9   GOOGL   3914 non-null   float64
#  10  LIN     3914 non-null   float64
#  11  META    3914 non-null   float64
#  12  MSFT    3914 non-null   float64
#  13  NFLX    3914 non-null   float64
#  14  NVDA    3914 non-null   float64
#  15  PLTR    3914 non-null   float64
#  16  TMUS    3914 non-null   float64
#  17  TSLA    3914 non-null   float64
#  18  ABBV    3914 non-null   float64
#  19  ABT     3914 non-null   float64
#  20  AXP     3914 non-null   float64
#  21  BABA    3914 non-null   float64
#  22  BAC     3914 non-null   float64
#  23  BRK-B   3914 non-null   float64
#  24  CAT     3914 non-null   float64
#  25  CCZ     3914 non-null   float64
#  26  CRM     3914 non-null   float64
#  27  CVX     3914 non-null   float64
#  28  DIS     3914 non-null   float64
#  29  GE      3914 non-null   float64
#  30  GS      3914 non-null   float64
#  31  HD      3914 non-null   float64
#  32  HSBC    3914 non-null   float64
#  33  IBM     3914 non-null   float64
#  34  JNJ     3914 non-null   float64
#  35  JPM     3914 non-null   float64
#  36  KO      3914 non-null   float64
#  37  LLY     3914 non-null   float64
#  38  MA      3914 non-null   float64
#  39  MCD     3914 non-null   float64
#  40  MRK     3914 non-null   float64
#  41  MS      3914 non-null   float64
#  42  NVO     3914 non-null   float64
#  43  NVS     3914 non-null   float64
#  44  ORCL    3914 non-null   float64
#  45  PG      3914 non-null   float64
#  46  PM      3914 non-null   float64
#  47  RTX     3914 non-null   float64
#  48  RY      3914 non-null   float64
#  49  SAP     3914 non-null   float64
#  50  SHEL    3914 non-null   float64
#  51  T       3914 non-null   float64
#  52  TM      3914 non-null   float64
#  53  TSM     3914 non-null   float64
#  54  UNH     3914 non-null   float64
#  55  V       3914 non-null   float64
#  56  WFC     3914 non-null   float64
#  57  WMT     3914 non-null   float64
#  58  XOM     3914 non-null   float64
# dtypes: float64(59)
# memory usage: 1.8 MB
# None
# ==================================================
# Min Date: 2010-01-04 00:00:00
# Max Date: 2025-07-25 00:00:00
# Start Rebalance Year: 2020
# Average number of trading days per month: 21 days
# ==================================================

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3914 entries, 2010-01-04 to 2025-07-25
# Data columns (total 59 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3914 non-null   float64
#  1   AMD     3914 non-null   float64
#  2   AMZN    3914 non-null   float64
#  3   ASML    3914 non-null   float64
#  4   AVGO    3914 non-null   float64
#  5   AZN     3914 non-null   float64
#  6   COST    3914 non-null   float64
#  7   CSCO    3914 non-null   float64
#  8   GOOG    3914 non-null   float64
#  9   GOOGL   3914 non-null   float64
#  10  LIN     3914 non-null   float64
#  11  META    3914 non-null   float64
#  12  MSFT    3914 non-null   float64
#  13  NFLX    3914 non-null   float64
#  14  NVDA    3914 non-null   float64
#  15  PLTR    3914 non-null   float64
#  16  TMUS    3914 non-null   float64
#  17  TSLA    3914 non-null   float64
#  18  ABBV    3914 non-null   float64
#  19  ABT     3914 non-null   float64
#  20  AXP     3914 non-null   float64
#  21  BABA    3914 non-null   float64
#  22  BAC     3914 non-null   float64
#  23  BRK-B   3914 non-null   float64
#  24  CAT     3914 non-null   float64
#  25  CCZ     3914 non-null   float64
#  26  CRM     3914 non-null   float64
#  27  CVX     3914 non-null   float64
#  28  DIS     3914 non-null   float64
#  29  GE      3914 non-null   float64
#  30  GS      3914 non-null   float64
#  31  HD      3914 non-null   float64
#  32  HSBC    3914 non-null   float64
#  33  IBM     3914 non-null   float64
#  34  JNJ     3914 non-null   float64
#  35  JPM     3914 non-null   float64
#  36  KO      3914 non-null   float64
#  37  LLY     3914 non-null   float64
#  38  MA      3914 non-null   float64
#  39  MCD     3914 non-null   float64
#  40  MRK     3914 non-null   float64
#  41  MS      3914 non-null   float64
#  42  NVO     3914 non-null   float64
#  43  NVS     3914 non-null   float64
#  44  ORCL    3914 non-null   float64
#  45  PG      3914 non-null   float64
#  46  PM      3914 non-null   float64
#  47  RTX     3914 non-null   float64
#  48  RY      3914 non-null   float64
#  49  SAP     3914 non-null   float64
#  50  SHEL    3914 non-null   float64
#  51  T       3914 non-null   float64
#  52  TM      3914 non-null   float64
#  53  TSM     3914 non-null   float64
#  54  UNH     3914 non-null   float64
#  55  V       3914 non-null   float64
#  56  WFC     3914 non-null   float64
#  57  WMT     3914 non-null   float64
#  58  XOM     3914 non-null   float64
# dtypes: float64(59)
# memory usage: 1.8 MB

# %%
###### Portfolio Type ######
long_only = tuple([0,1])
long_short = tuple([-1,1])

port_type = long_only

# %% [markdown]
# # Training

# %%
# Directory to save the results
output_dir = 'Results_NoCons'
model_type = 'Transformer'  # 'Transformer' or 'LSTM'
pe_type = 'tAPE'          
# 'OriPE', 'Time2Vec', 
# 'ConvSPE', 'SineSPE', 
# 'TemporalPE', 'LearnablePE', 
# 'AbsolutePE', 'tAPE'
pre_post = 'PostNorm'       # 'PostNorm' or 'PreNorm'
n_temp = 1.0
train_type = f'01_2_{model_type}_{pe_type}_{pre_post}_temp_{n_temp}'  # '01_1', '01_2', '01_3', etc.
loss_type = 'maximize_return'  # เลือก 'sharpe', 'sortino', หรือ 'maximize_return'
run_no = f'12_{loss_type}'  # '1', '2', '3', etc.

# --- เริ่มโค้ดสำหรับบันทึก Excel ---
results_excel_path = f"{output_dir}/{train_type}/01_Results_{model_type}_{pe_type}_{pre_post}_run_{run_no}.xlsx"

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Dropout, LayerNormalization, MultiHeadAttention, Embedding, GlobalAveragePooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
from dateutil.parser import parse
from tensorflow.keras import layers, Model
from tensorflow.keras.models import Model as KModel, Sequential
from tensorflow.keras import layers, Model as KModel
import cvxpy as cp
import cvxopt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Layer


devices = tf.config.list_physical_devices()
print("\nDevices: ", devices)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  details = tf.config.experimental.get_device_details(gpus[0])
  print("GPU details: ", details)
warnings.filterwarnings('ignore')
# Out:
# Devices:  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU details:  {'device_name': 'METAL'}

# %% [markdown]
# # Model

# %%
class Model:
    def __init__(self, max_weight=1, asset_map=None, asset_lower=None, asset_upper=None, port_type=None, loss_type=loss_type):
        self.data = None
        self.model = None
        self.max_weight = max_weight
        self.asset_map = asset_map or {}
        self.asset_lower = asset_lower or {}
        self.asset_upper = asset_upper or {}
        self.port_type = port_type
        self.asset_columns = None
    def _create_constraint_matrices(self, columns):
        """Create constraint matrices for asset‐type bounds."""
        self.asset_columns = columns
        
        asset_types = {}
        for asset in columns:
            t = self.asset_map.get(asset, "Unknown")
            asset_types.setdefault(t, []).append(asset)
        
        mats = []
        lbs = []
        ubs = []
        names = []
        for t, assets in asset_types.items():
            vec = np.zeros(len(columns), dtype=float)
            for a in assets:
                idx = columns.get_loc(a)
                vec[idx] = 1.0
            mats.append(vec)
            lbs.append(self.asset_lower.get(t, 0.0))
            ubs.append(self.asset_upper.get(t, 1.0))
            names.append(t)
        
        self.constraint_matrix = np.vstack(mats)        # shape = (n_types, n_assets)
        self.lower_bounds = np.array(lbs, dtype=float)  # shape = (n_types,)
        self.upper_bounds = np.array(ubs, dtype=float)  # shape = (n_types,)
        self.asset_type_names = names
     
    def _apply_constraints_final(self, weights):
        """
        ใช้ Mixed-Integer Programming (MIP) เพื่อบังคับ:
        • Σw = 1
        • per-asset cap 0.30 (SHV 0.40)
        • asset_lower / asset_upper (ส่วนนี้ถูกปิดไว้ในโค้ดเดิม)
        • ลดการขยับจาก w0 โดยเฉพาะตำแหน่งที่ w0 == 0
        • ***ใหม่: บังคับให้มีสินทรัพย์ในพอร์ต 10-15 ตัว***
        """
        w0 = np.asarray(weights, float).copy()
        n = w0.size

        # ---------- ตัวแปร MIP ----------------------------------------------------
        w = cp.Variable(n, name='weights') # น้ำหนักต่อเนื่อง
        b = cp.Variable(n, boolean=True, name='selection_vars') # ตัวแปร Binary สำหรับเลือกว่าจะลงทุนในสินทรัพย์หรือไม่

        # ---------- สร้างขอบเขตรายตัว (Bounds) -----------------------------------
        ub_val = np.full(n, 0.30)
        # if self.asset_columns is not None and "SHV" in self.asset_columns:
        #     ub_val[self.asset_columns.get_loc("SHV")] = 0.40
        lb_val = np.full(n, self.port_type[0])

        # ---------- สร้างข้อจำกัด (Constraints) --------------------------------
        constraints = [
            cp.sum(w) == 1,
            w >= lb_val,
            w <= ub_val
        ]

        # === ส่วนที่เพิ่มเข้ามาสำหรับ MIP ===
        # 1. ข้อจำกัดเรื่องจำนวนสินทรัพย์
        constraints += [
            cp.sum(b) >= 2,
            cp.sum(b) <= 10
        ]

        # 2. เชื่อมโยงตัวแปร w และ b (Big-M Method)
        #    - ถ้า b[i] = 0 แล้ว w[i] ต้องเป็น 0
        #    - ถ้า b[i] = 1 แล้ว w[i] สามารถมีค่าได้ถึง upper bound
        #    - ค่า M ควรมีขนาดใหญ่พอ แต่ไม่ใหญ่เกินไป ในที่นี้ใช้ Upper Bound ของน้ำหนัก
        M = 1.0 
        constraints += [
            w <= M * b,
            w >= 0 # ต้องมั่นใจว่าน้ำหนักไม่ติดลบเมื่อใช้กับ Big-M
        ]
        # =================================

        # ---------- Objective: min Σ α_i |w_i - w0_i| ------------------------
        # พยายามหาน้ำหนักที่ใกล้เคียงกับ raw_weights ที่สุดภายใต้ข้อจำกัดทั้งหมด
        eps = 1e-4
        alpha = 1.0 / (np.abs(w0) + eps) # ทำให้โมเดลพยายามรักษาสินทรัพย์ที่ได้ raw_weight สูงๆ ไว้
        obj = cp.Minimize(cp.sum(cp.multiply(alpha, cp.abs(w - w0)))) # L1 Norm

        prob = cp.Problem(obj, constraints)

        # แก้ปัญหา MIP (ต้องใช้ Solver ที่รองรับ)
        # ECOS_BB เป็น Solver ที่มาพร้อม cvxpy และรองรับ MIP
        # หากต้องการประสิทธิภาพที่ดีกว่า อาจต้องติดตั้ง Solver เพิ่มเติม เช่น GLPK_MI, CBC, SCIP
        try:
            print("Solving MIP with ECOS_BB...")
            prob.solve(solver=cp.ECOS_BB, verbose=False)
        except cp.error.SolverError as e:
            print(f"ECOS_BB failed: {e}. Trying with GLPK_MI...")
            try:
                # ลองใช้ GLPK_MI ถ้าติดตั้งไว้
                prob.solve(solver=cp.GLPK_MI, verbose=False)
            except cp.error.SolverError:
                print("MIP solver failed. Falling back to original QP method without asset count constraint.")
                # หากแก้ MIP ไม่ได้จริงๆ ให้กลับไปใช้วิธีเดิม (ไม่มี constraint จำนวนหุ้น)
                return self._apply_constraints_final_original(weights) # สมมติว่ามีฟังก์ชัน QP เดิมอยู่

        if w.value is None:
            print("QP infeasible or solver failed, falling back to greedy method.")
            # อาจจะต้องมี fallback logic ที่นี่
            return super()._apply_constraints(weights)

        return np.asarray(w.value).flatten()

    # เพิ่มฟังก์ชัน QP เดิมสำรองไว้กรณี MIP ล้มเหลว
    def _apply_constraints_final_original(self, weights):
        w0 = np.asarray(weights, float).copy()
        n = w0.size
        ub = np.full(n, 0.30)
        lb = np.full(n, self.port_type[0])
        w = cp.Variable(n)
        constraints = [cp.sum(w) == 1, w >= lb, w <= ub]
        eps = 1e-4
        alpha = 1.0 / (w0 + eps)
        obj = cp.Minimize(cp.sum(cp.multiply(alpha, cp.abs(w - w0))))
        prob = cp.Problem(obj, constraints)
        try:
            prob.solve(solver=cp.OSQP)
        except cp.error.SolverError:
            prob.solve(solver=cp.ECOS)
        if w.value is None:
            return super()._apply_constraints(weights)
        return np.asarray(w.value).flatten()

    
    def build(self, input_shape, outputs, PE_type=pe_type, loss_type=loss_type):

        d_model = 512
        num_heads = 8
        ff_dim = 2048
        num_layers = 6
        dropout_rate = 0.3
        spe_kernel_size = 5

        seq_len, feature_dim = input_shape

        def get_positional_encoding(length, depth):
            # Halve the depth because we will concatenate sine and cosine embeddings.
            depth = depth / 2

            # Create arrays for positions and depths.
            positions = np.arange(length)[:, np.newaxis]      # Shape: (length, 1)
            depths = np.arange(depth)[np.newaxis, :] / depth  # Shape: (1, depth)

            # Calculate the angle rates.
            angle_rates = 1 / (10000**depths)                 # Shape: (1, depth)

            # Calculate the angle radians.
            angle_rads = positions * angle_rates             # Shape: (length, depth)

            # Concatenate the sine and cosine of the angle radians to form the encoding.
            pos_encoding = np.concatenate(
                [np.sin(angle_rads), np.cos(angle_rads)],
                axis=-1) 
            # Cast the final encoding to a float32 TensorFlow tensor.
            return tf.cast(pos_encoding, dtype=tf.float32)
        
        inputs = layers.Input(shape=(seq_len, feature_dim))

        # ====== Position Encoding ======
        if PE_type == 'OriPE':
            x = layers.Dense(d_model)(inputs)
            pos_encoding = get_positional_encoding(seq_len, d_model)
            x = x + pos_encoding[tf.newaxis, :]
        elif PE_type == 'Time2Vec':
            time_embedding = Time2Vector(seq_len)(inputs)
            x = layers.Concatenate(axis=-1)([inputs, time_embedding])
            x = layers.Dense(d_model)(x)
        elif PE_type == 'ConvSPE':
            x = layers.Dense(d_model)(inputs)
            x = ConvSPE(d_model=d_model, kernel_size=spe_kernel_size)(x)
        elif PE_type == 'SineSPE':
            x = layers.Dense(d_model)(inputs)
            x = SineSPE(d_model=d_model, max_len=seq_len + 100)(x)
        elif PE_type == 'TemporalPE':
            x = layers.Dense(d_model)(inputs)
            x = TemporalPositionalEncoding(d_model=d_model, max_len=seq_len + 100)(x)
        elif PE_type == 'LearnablePE':
            x = layers.Dense(d_model)(inputs)
            pos_encoding_layer = LearnablePositionalEncoding(d_model=d_model, max_len=seq_len + 100, dropout=dropout_rate)
            x = pos_encoding_layer(x)
        elif PE_type == 'AbsolutePE':
            x = layers.Dense(d_model)(inputs)
            pos_encoding_layer = AbsolutePositionalEncoding(d_model=d_model, max_len=seq_len + 100, dropout=dropout_rate)
            x = pos_encoding_layer(x)
        elif PE_type == 'tAPE':
            x = layers.Dense(d_model)(inputs)
            pos_encoding_layer = tAPE(d_model=d_model, max_len=seq_len + 100, dropout=dropout_rate)
            x = pos_encoding_layer(x)
        else:
            raise ValueError(f"Unknown Positional Encoding type: {PE_type}")

        for _ in range(num_layers):
            attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
            attn_output = layers.Dropout(dropout_rate)(attn_output)
            out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)

            ffn = layers.Dense(ff_dim, activation="relu")(out1) # ori = relu
            ffn = layers.Dense(d_model)(ffn)
            ffn_output = layers.Dropout(dropout_rate)(ffn)
            x = layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

        pooled = layers.GlobalAveragePooling1D()(x)       # (batch_size, d_model)
        # outputs_layer = layers.Dense(outputs, activation="softmax")(pooled)
        
        # use TemperatureSoftmax for softmax with temperature scaling
        outputs_layer = layers.Dense(outputs)(pooled)
        outputs_layer = TemperatureSoftmax(temperature=n_temp)(outputs_layer) 
          
        # outputs_layer = layers.Dense(outputs, activation=TemperatureSoftmax(3.0))(pooled)  

        model = KModel(inputs=inputs, outputs=outputs_layer)
                     
        # Modify Sharpe loss function
        def sharpe_loss(_, weights):
            w = weights[0]
            # 1. คำนวณอนุกรมเวลาผลตอบแทนรายวันของพอร์ต
            portfolio_returns_daily = tf.reduce_sum(tf.multiply(self.data, w), axis=1)
            # 2. คำนวณค่าสถิติรายวัน
            mean_daily_return = tf.reduce_mean(portfolio_returns_daily)
            std_daily_return = tf.math.reduce_std(portfolio_returns_daily)
            # 3. แปลงเป็นค่ารายปี (Annualize)
            annualized_return = mean_daily_return * 252
            annualized_volatility = std_daily_return * tf.sqrt(252.0) # ต้อง sqrt() จำนวนวัน
            # 4. คำนวณ Sharpe Ratio ด้วยหน่วยเวลาที่สอดคล้องกัน
            risk_free_rate = 0.02
            sharpe = (annualized_return - risk_free_rate) / (annualized_volatility + 1e-8) # เพิ่ม epsilon เพื่อความเสถียร
            return -sharpe

        
        def sortino_loss(_, weights):
            w = weights[0]
            # 1. คำนวณอนุกรมเวลาผลตอบแทนรายวันของพอร์ต (Calculate daily portfolio returns time series)
            portfolio_returns_daily = tf.reduce_sum(tf.multiply(self.data, w), axis=1)

            # 2. กำหนดอัตราผลตอบแทนที่ปราศจากความเสี่ยง (Define risk-free rate)
            risk_free_rate_annual = 0.02
            # แปลงเป็นรายวันเพื่อใช้เป็น target return (Convert to daily for target return)
            daily_target_return = risk_free_rate_annual / 252.0

            # 3. คำนวณผลตอบแทนเฉลี่ยและแปลงเป็นรายปี (Calculate mean return and annualize)
            mean_daily_return = tf.reduce_mean(portfolio_returns_daily)
            annualized_return = mean_daily_return * 252.0

            # 4. คำนวณ Downside Deviation
            # 4.1 หาเฉพาะผลตอบแทนที่ต่ำกว่าเป้าหมาย (Find only returns below the target)
            downside_returns = tf.minimum(0.0, portfolio_returns_daily - daily_target_return)
            
            # 4.2 คำนวณ Downside Deviation รายวัน (Calculate daily Downside Deviation)
            # คือรากที่สองของค่าเฉลี่ยของผลตอบแทนที่ต่ำกว่าเป้าหมายยกกำลังสอง
            # (It's the square root of the mean of squared returns below the target)
            squared_downside_returns = tf.square(downside_returns)
            mean_squared_downside = tf.reduce_mean(squared_downside_returns)
            downside_deviation_daily = tf.sqrt(mean_squared_downside)

            # 4.3 แปลงเป็นรายปี (Annualize)
            annualized_downside_deviation = downside_deviation_daily * tf.sqrt(252.0)

            # 5. คำนวณ Sortino Ratio
            sortino = (annualized_return - risk_free_rate_annual) / (annualized_downside_deviation + 1e-8) # เพิ่ม epsilon เพื่อความเสถียร

            # เราต้องการ maximize Sortino Ratio ดังนั้น loss function คือค่าลบของมัน
            # (We want to maximize the Sortino Ratio, so the loss function is its negative)
            return -sortino

        def maximize_return_loss(_, weights):
            w = weights[0]
            # 1. คำนวณอนุกรมเวลาผลตอบแทนรายวันของพอร์ต (Calculate daily portfolio returns time series)
            portfolio_returns_daily = tf.reduce_sum(tf.multiply(self.data, w), axis=1)

            # 2. คำนวณผลตอบแทนเฉลี่ยรายวัน (Calculate mean daily return)
            mean_daily_return = tf.reduce_mean(portfolio_returns_daily)

            # 3. แปลงเป็นผลตอบแทนรายปี (Annualize return)
            annualized_return = mean_daily_return * 252.0

            # 4. เราต้องการ maximize return ดังนั้น loss function คือค่าลบของมัน
            # (We want to maximize the return, so the loss function is its negative)
            return -annualized_return

        # === เลือก Loss และ Compile Model ===
        if loss_type == 'sharpe':
            loss_function = sharpe_loss
            print("Compiling model with Sharpe Loss.")
        elif loss_type == 'sortino':
            loss_function = sortino_loss
            print("Compiling model with Sortino Loss.")
        elif loss_type == 'maximize_return':
            loss_function = maximize_return_loss
            print("Compiling model with Maximize Return Loss.")
        else:
            raise ValueError(f"Unknown loss_type: {loss_type}")

        optimizer = tf.keras.optimizers.Adam()
        model.compile(loss=loss_function, optimizer=optimizer)
      
        return model

    def calc_wgts(self, lkbk: int, ep: int, data: pd.DataFrame, features: pd.DataFrame, patience=10, PE_type=pe_type, loss_type=loss_type):
        # Ensure constraint matrices exist
        if not hasattr(self, "constraint_matrix"):
            self._create_constraint_matrices(data.columns)

        print(f"=== Calculating weights with lkbk={lkbk}, ep={ep}, patience={patience}, PE_type={PE_type}, loss_type={loss_type} ===")

        # Scale the features
        features = [features.shift(k).fillna(0).values[lkbk:] for k in range(lkbk)]
        
        # Create Numpy array from features
        data_array = np.concatenate(features, axis=1)
                    
        # Split off train set
        data = data.iloc[lkbk:]
        
        # Convert data to tensorflow format for processing in loss function
        self.data = tf.cast(tf.constant(data), float)

        # Building a new model (create fresh model for each rebalance)
        self.model = self.build(data_array.shape, len(data.columns), PE_type=PE_type, loss_type=loss_type)
        
        early_stopping = EarlyStopping(monitor='loss', patience=patience, restore_best_weights=True)

        # Adding a new axis to features
        fit_predict_data = data_array[np.newaxis, :]

        # Adding new axis to classifier
        """Extending the length of the output vector"""
        y = np.zeros(len(data.columns))[np.newaxis, :]

        print(f"X shape: {fit_predict_data.shape}")
        # print("X:", fit_predict_data)
        print("y shape:", ep)
        # print("y:", y)
        # Fit the model  
        self.model.fit(fit_predict_data, y, epochs=ep, shuffle=False, callbacks=[early_stopping])

        # Predict weights
        raw_weights = self.model.predict(fit_predict_data)[0]
        raw_weights_non_zero_count = np.count_nonzero(raw_weights)
        print(f"Raw Weights selected ETF: {raw_weights_non_zero_count}")
        # Apply constraints
        weights = self._apply_constraints_final(raw_weights)
        return weights, raw_weights

# %%
# asset_weights = model.calc_wgts(lookback, n_epochs, train_features, train_features, patience=10)
def quarterly_walk_forward(df, lookback, n_epochs, features, asset_map=None, 
                                   asset_lower=None, asset_upper=None, port_type=(0, 1), 
                                   start_year=2020, trading_days_per_quarter=63, 
                                   min_train_periods=252, PE_type=pe_type, n_patience=10, loss_type=loss_type):
    """Optimized quarterly walk-forward analysis"""
    
    # Efficient data preparation
    original_index = df.index
    df_reset = df.reset_index(drop=True)
    features_reset = features.reset_index(drop=True)
    
    # Get rebalance dates
    rebalance_dates = get_rebalance_dates(df, start_year)
    
    # Pre-allocate result containers
    all_rets = []
    weights_list = []
    raw_weights_list = []
    rebalance_info = []
    
    # Initialize model once
    model = Model(
        max_weight=1, 
        asset_map=asset_map, 
        asset_lower=asset_lower,
        asset_upper=asset_upper, 
        port_type=port_type
    )
    
    print(f"\n=== Starting Optimized Quarterly Rebalancing Analysis ===")
    print(f"Training lookback period: {lookback} days")
    print(f"Minimum training periods: {min_train_periods} days")
    print(f"Trading days per quarter: {trading_days_per_quarter} days")
    print(f"Total rebalance periods: {len(rebalance_dates)}")
    
    for i, rebalance_date in enumerate(rebalance_dates):
        print(f"\n--- Rebalancing {i+1}/{len(rebalance_dates)} ---")
        print(f"Rebalance Date: {rebalance_date.strftime('%Y-%m-%d')}")
        
        try:
            # More efficient position finding
            train_end_pos = original_index.get_indexer([rebalance_date], method='pad')[0] - 1
            if train_end_pos < 0:
                continue
                
        except Exception:
            print(f"Cannot find position for {rebalance_date}, skipping... ❌❌❌")
            continue
        
        # Define training period
        train_start_pos = max(0, train_end_pos - min_train_periods)
        
        print(f"Training period: {original_index[train_start_pos].strftime('%Y-%m-%d')} to {original_index[train_end_pos].strftime('%Y-%m-%d')}")
        print(f"Training days: {train_end_pos - train_start_pos + 1}")
        
        # Get quarter end
        quarter_end = get_quarter_end_date(rebalance_date, original_index, trading_days_per_quarter)
        
        try:
            test_end_pos = original_index.get_loc(quarter_end)
            print(f"Test period: {rebalance_date.strftime('%Y-%m-%d')} to {quarter_end.strftime('%Y-%m-%d')}")
            print(f"Test days: {test_end_pos - train_end_pos}")
        except Exception:
            print(f"Cannot find end date for quarter, skipping... ❌❌❌")
            continue
        
        # Skip if insufficient future data
        if test_end_pos >= len(df_reset):
            print(f"Not enough future data, stopping at rebalance {i+1} ❌❌❌")
            break
        
        # Extract and prepare training data more efficiently
        train_data = df_reset.iloc[train_start_pos:train_end_pos+1].copy()
        train_features = features_reset.iloc[train_start_pos:train_end_pos+1].copy()
        
        # Efficient data cleaning
        train_data = train_data.ffill().bfill()
        train_features = train_features.fillna(0) # for cal sharpe loss (ori pct_change)
        # train_features_roll = train_features.rolling(window=5, min_periods=1).mean().fillna(0)

        # # # scale features - for training
        #sc = StandardScaler()
        #train_features_sc = train_features.copy()
        # train_features_sc = train_features_sc.rolling(window=5, min_periods=1).mean().fillna(0)
        #train_features_sc = pd.DataFrame(sc.fit_transform(train_features_sc), columns=train_features.columns, index=train_features.index)
        
        # Calculate test returns more efficiently
        test_data = df_reset.iloc[train_end_pos:test_end_pos+1].copy()
        test_returns = test_data.pct_change().fillna(0).iloc[1:]

        print(f"Training data shape: {train_data.shape}")
        print(f"Test returns shape: {test_returns.shape}")
        
        # Train model and get weights
        try:
            # Clear session for memory management
            K.clear_session()
            tf.keras.backend.clear_session()
            
            # asset_weights = model.calc_wgts(lookback, n_epochs, train_data, train_features, patience=10)
            asset_weights, raw_weights = model.calc_wgts(lookback, n_epochs, 
                                                         train_features, train_features, 
                                                         patience=n_patience, 
                                                         PE_type=PE_type,
                                                         loss_type=loss_type)
            #asset_weights, raw_weights = model.calc_wgts(lookback, n_epochs, train_features, train_features_sc, patience=10)

            print(f"\n{'=' * 30}")
            # total weight should be 1 status
            total_weight = np.sum(asset_weights).round(4)
            if total_weight == 1:
                print(f"Total weight: {total_weight:.4f} ✅")
            else:
                print(f"Total weight: {total_weight:.4f} ❌ (should be 1.0)")
            
            weights_non_zero_count = np.count_nonzero(asset_weights)
            print(f"Selected ETF count: {weights_non_zero_count}")
            # if weights_non_zero_count < 10 or weights_non_zero_count > 15:
            #     print(f"Warning: weights have {weights_non_zero_count} ❌")
            #     os.system(f'say "Warning: Selected ETF have {weights_non_zero_count}"')
            # if weights_non_zero_count >= 10 and weights_non_zero_count <= 15:
            #     print(f"Selected ETF: {weights_non_zero_count} ✅")

            # Print allocation summary
            if hasattr(model, 'constraint_matrix') and hasattr(model, 'asset_type_names'):
                type_weights = np.dot(model.constraint_matrix, asset_weights)
                print("Asset Type Allocation:")
                for j, (asset_type, weight) in enumerate(zip(model.asset_type_names, type_weights)):
                    lower = model.asset_lower.get(asset_type, 0.0)
                    upper = model.asset_upper.get(asset_type, 1.0)
                    # status
                    if lower <= weight.round(4) <= upper:
                        status = "✅" #Within Range
                    else:
                        status = "❌" #Out of Range
                    print(f"  {asset_type}: {weight:.3f} ({weight*100:.2f}%) [Range: {lower:.2f}-{upper:.2f}] {status}")
            
            # Calculate out-of-sample returns
            if len(test_returns) > 0:
                # Vectorized return calculation
                oos_returns = (test_returns.values * asset_weights).sum(axis=1)
                oos_returns = pd.Series(oos_returns, index=test_returns.index)
                
                all_rets.append(oos_returns)
                weights_list.append(asset_weights)
                raw_weights_list.append(raw_weights)
                rebalance_info.append({
                    'rebalance_date': rebalance_date,
                    'quarter_end': quarter_end,
                    'quarter_return': oos_returns.sum(),
                    'quarter_days': len(oos_returns)
                })
                
                print(f"Quarter return: {oos_returns.sum():.4f} ({oos_returns.sum()*100:.2f}%)")
            else:
                print("No test returns available ❌❌❌")
            
            print(f"\n{'=' * 30}")
                
        except Exception as e:
            print(f"Error in rebalancing: {str(e)} ❌❌❌")
            continue
    
    # Combine results efficiently
    if all_rets:
        pnl = pd.concat(all_rets, ignore_index=False)
        weights_df = pd.DataFrame(weights_list, columns=df.columns)
        raw_weights_df = pd.DataFrame(raw_weights_list, columns=df.columns)
        rebalance_summary = pd.DataFrame(rebalance_info)
        
        print(f"\n=== Rebalancing Summary ===")
        print(f"Total quarters processed: {len(rebalance_info)}")
        print(f"Total return periods: {len(pnl)}")
        print(f"Average quarterly return: {rebalance_summary['quarter_return'].mean():.4f}")
        print(f"Quarterly return std: {rebalance_summary['quarter_return'].std():.4f}")
        
        return pnl, weights_df, rebalance_summary, raw_weights_df
    else:
        print("No successful rebalancing periods ❌❌❌")
        return None, None, None

# %%
data_train = data.copy()
features = data_train.pct_change().fillna(0)  # Calculate percentage change for features

# Reset states generated by Keras
K.clear_session()

set_seed(1)

n_lookback = avg_days * 12 # Sequence: โค้ดจะสร้าง Input โดยสำหรับ ทุกๆ วัน ในชุดข้อมูลเทรน มันจะ "มองย้อนกลับไป" เป็นจำนวน n_lookback วัน (เช่น 21 วันทำการ หรือประมาณ 1 เดือน)
n_trading_days_per_quarter = avg_days * 3  # 21 days/month * 3 months = 63 days
n_min_train_periods = avg_days * 12 * 3   # 3 years of training data = 252*3 days = 756 days

print(f"Lookback period: {n_lookback} days")
print(f"Trading days per quarter: {n_trading_days_per_quarter} days")
print(f"Minimum training periods: {n_min_train_periods} days")
# Out:
# Lookback period: 252 days
# Trading days per quarter: 63 days
# Minimum training periods: 756 days

# %%
# Run quarterly rebalancing with constraints
pnl, model_weights, rebalance_summary, Model_raw_weights = quarterly_walk_forward(
    data_train, 
    lookback=n_lookback, 
    n_epochs=10, 
    features=features.fillna(0),
    # asset_map=asset_map, 
    # asset_lower=asset_lower_aggressive,
    # asset_upper=asset_upper_aggressive,
    port_type=long_only,
    start_year=start_rebalance_year,
    trading_days_per_quarter=n_trading_days_per_quarter,  
    min_train_periods=n_min_train_periods,
    PE_type=pe_type,
    n_patience=10,
    loss_type=loss_type
)
# Out:
# Rebalance Dates: ['2020-01-02', '2020-04-01', '2020-07-01', '2020-10-01', '2021-01-04', '2021-04-01', '2021-07-01', '2021-10-01', '2022-01-03', '2022-04-01', '2022-07-01', '2022-10-03', '2023-01-03', '2023-04-03', '2023-07-03', '2023-10-02', '2024-01-02', '2024-04-01', '2024-07-01', '2024-10-01', '2025-01-02', '2025-04-01', '2025-07-01']
#
# === Starting Optimized Quarterly Rebalancing Analysis ===
# Training lookback period: 252 days
# Minimum training periods: 756 days
# Trading days per quarter: 63 days
# Total rebalance periods: 23
#
# --- Rebalancing 1/23 ---
# Rebalance Date: 2020-01-02
# Training period: 2016-12-28 to 2019-12-31
# Training days: 757
# Test period: 2020-01-02 to 2020-04-01
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# 2025-11-02 13:26:38.113436: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2025-11-02 13:26:38.113603: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-11-02 13:26:38.113609: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2025-11-02 13:26:38.114094: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-02 13:26:38.114109: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 2025-11-02 13:26:41.198558: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: -0.1703
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step - loss: -0.9040
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step - loss: -0.9041
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - loss: -0.9041
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - loss: -0.9041
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - loss: -0.9041
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: -0.9041
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - loss: -0.9041
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: -0.9041
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - loss: -0.9041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0034 (0.34%)
#
# ==============================
#
# --- Rebalancing 2/23 ---
# Rebalance Date: 2020-04-01
# Training period: 2017-03-29 to 2020-03-31
# Training days: 757
# Test period: 2020-04-01 to 2020-06-30
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: -0.1084
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step - loss: -0.9500
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step - loss: -0.9607
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step - loss: -0.9607
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - loss: -0.9607
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step - loss: -0.9607
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step - loss: -0.9607
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step - loss: -0.9607
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step - loss: -0.9607
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step - loss: -0.9607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.2380 (23.80%)
#
# ==============================
#
# --- Rebalancing 3/23 ---
# Rebalance Date: 2020-07-01
# Training period: 2017-06-28 to 2020-06-30
# Training days: 757
# Test period: 2020-07-01 to 2020-09-29
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: -0.1959
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 857ms/step - loss: -0.8081
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - loss: -0.8158
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - loss: -0.0759
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step - loss: -0.1148
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - loss: 0.2311
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 0.0999
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - loss: -0.0460
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: -0.1281
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: -0.4842
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: -0.0026 (-0.26%)
#
# ==============================
#
# --- Rebalancing 4/23 ---
# Rebalance Date: 2020-10-01
# Training period: 2017-09-28 to 2020-09-30
# Training days: 757
# Test period: 2020-10-01 to 2020-12-30
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: -0.1643
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step - loss: -1.1796
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - loss: -1.2470
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step - loss: -1.2470
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - loss: -1.2470
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step - loss: -1.2470
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - loss: -1.2470
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - loss: -1.2470
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: -1.2470
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - loss: -1.2470
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.1476 (14.76%)
#
# ==============================
#
# --- Rebalancing 5/23 ---
# Rebalance Date: 2021-01-04
# Training period: 2017-12-29 to 2020-12-31
# Training days: 757
# Test period: 2021-01-04 to 2021-04-05
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: -0.2912
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step - loss: -0.8742
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step - loss: -1.4433
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: -1.4433
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - loss: -1.4433
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - loss: -1.4433
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step - loss: -1.4433
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: -1.4433
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - loss: -1.4433
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - loss: -1.4433
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x47c907f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0168 (1.68%)
#
# ==============================
#
# --- Rebalancing 6/23 ---
# Rebalance Date: 2021-04-01
# Training period: 2018-03-29 to 2021-03-31
# Training days: 757
# Test period: 2021-04-01 to 2021-06-30
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: -0.2792
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step - loss: -1.1326
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step - loss: -1.5184
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step - loss: -1.5184
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step - loss: -1.5184
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step - loss: -1.5184
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step - loss: -1.5184
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step - loss: -1.5184
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 871ms/step - loss: -1.5184
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step - loss: -1.5184
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x47c5e91c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0321 (3.21%)
#
# ==============================
#
# --- Rebalancing 7/23 ---
# Rebalance Date: 2021-07-01
# Training period: 2018-06-28 to 2021-06-30
# Training days: 757
# Test period: 2021-07-01 to 2021-09-29
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - loss: -0.2947
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - loss: -1.6310
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step - loss: -1.6380
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - loss: -1.6380
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - loss: -1.6380
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - loss: -1.6380
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - loss: -1.6380
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step - loss: -1.6380
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: -1.6380
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: -1.6380
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0802 (8.02%)
#
# ==============================
#
# --- Rebalancing 8/23 ---
# Rebalance Date: 2021-10-01
# Training period: 2018-09-28 to 2021-09-30
# Training days: 757
# Test period: 2021-10-01 to 2021-12-30
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: -0.2960
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 891ms/step - loss: -1.5189
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step - loss: -1.6572
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - loss: -1.6572
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step - loss: -1.6572
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - loss: -1.6572
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - loss: -1.6572
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - loss: -1.6572
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step - loss: -1.6572
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step - loss: -1.6572
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.1888 (18.88%)
#
# ==============================
#
# --- Rebalancing 9/23 ---
# Rebalance Date: 2022-01-03
# Training period: 2019-01-02 to 2021-12-31
# Training days: 757
# Test period: 2022-01-03 to 2022-04-01
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: -0.2928
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.5434
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step - loss: -1.5436
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step - loss: -1.5436
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step - loss: -1.5436
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - loss: -1.5436
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step - loss: -1.5436
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step - loss: -1.5436
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step - loss: -1.5436
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - loss: -1.5436
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: -0.0326 (-3.26%)
#
# ==============================
#
# --- Rebalancing 10/23 ---
# Rebalance Date: 2022-04-01
# Training period: 2019-04-02 to 2022-03-31
# Training days: 757
# Test period: 2022-04-01 to 2022-07-01
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: -0.3588
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step - loss: -1.3752
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 796ms/step - loss: -1.3846
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 818ms/step - loss: -1.3846
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.3846
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.3846
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.3846
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: -1.3846
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: -1.3846
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.3846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: -0.2138 (-21.38%)
#
# ==============================
#
# --- Rebalancing 11/23 ---
# Rebalance Date: 2022-07-01
# Training period: 2019-07-01 to 2022-06-30
# Training days: 757
# Test period: 2022-07-01 to 2022-09-29
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: -0.2015
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step - loss: -0.7241
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step - loss: -0.8246
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 747ms/step - loss: -0.8246
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step - loss: -0.8246
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step - loss: -0.8246
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 776ms/step - loss: -0.8246
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step - loss: -0.8246
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.8246
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 876ms/step - loss: -0.8246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0269 (2.69%)
#
# ==============================
#
# --- Rebalancing 12/23 ---
# Rebalance Date: 2022-10-03
# Training period: 2019-10-01 to 2022-09-30
# Training days: 757
# Test period: 2022-10-03 to 2022-12-30
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: -0.1184
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.4422
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.4616
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.4616
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step - loss: -0.4616
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step - loss: -0.4616
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step - loss: -0.4616
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step - loss: -0.4616
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.4616
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step - loss: -0.4616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0980 (9.80%)
#
# ==============================
#
# --- Rebalancing 13/23 ---
# Rebalance Date: 2023-01-03
# Training period: 2019-12-31 to 2022-12-30
# Training days: 757
# Test period: 2023-01-03 to 2023-04-03
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: -0.0872
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step - loss: -0.2457
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step - loss: -0.4241
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - loss: -0.4606
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step - loss: -0.4606
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - loss: -0.4606
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step - loss: -0.4606
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step - loss: -0.4606
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - loss: -0.4606
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step - loss: -0.4606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0348 (3.48%)
#
# ==============================
#
# --- Rebalancing 14/23 ---
# Rebalance Date: 2023-04-03
# Training period: 2020-03-31 to 2023-03-31
# Training days: 757
# Test period: 2023-04-03 to 2023-07-03
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: -0.1050
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.3651
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - loss: -0.5397
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step - loss: -0.5397
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step - loss: -0.5397
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 816ms/step - loss: -0.5397
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 780ms/step - loss: -0.5397
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - loss: -0.5397
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step - loss: -0.5397
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step - loss: -0.5397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.1720 (17.20%)
#
# ==============================
#
# --- Rebalancing 15/23 ---
# Rebalance Date: 2023-07-03
# Training period: 2020-06-29 to 2023-06-30
# Training days: 757
# Test period: 2023-07-03 to 2023-09-29
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: -0.0978
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.3844
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step - loss: -0.4075
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step - loss: -0.4925
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.5420
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step - loss: -0.5420
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step - loss: -0.5420
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - loss: -0.5420
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - loss: -0.5420
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - loss: -0.5420
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0725 (7.25%)
#
# ==============================
#
# --- Rebalancing 16/23 ---
# Rebalance Date: 2023-10-02
# Training period: 2020-09-28 to 2023-09-29
# Training days: 757
# Test period: 2023-10-02 to 2023-12-29
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: -0.0853
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.4870
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 807ms/step - loss: -0.5182
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step - loss: -0.5182
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step - loss: -0.5182
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step - loss: -0.5182
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step - loss: -0.5182
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - loss: -0.5182
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - loss: -0.5182
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - loss: -0.5182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.1175 (11.75%)
#
# ==============================
#
# --- Rebalancing 17/23 ---
# Rebalance Date: 2024-01-02
# Training period: 2020-12-28 to 2023-12-29
# Training days: 757
# Test period: 2024-01-02 to 2024-04-02
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: -0.0974
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.2957
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step - loss: -0.4083
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - loss: -0.4190
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step - loss: -0.4190
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step - loss: -0.4190
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step - loss: -0.4190
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step - loss: -0.4190
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 775ms/step - loss: -0.4190
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step - loss: -0.4190
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 781ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.3625 (36.25%)
#
# ==============================
#
# --- Rebalancing 18/23 ---
# Rebalance Date: 2024-04-01
# Training period: 2021-03-26 to 2024-03-28
# Training days: 757
# Test period: 2024-04-01 to 2024-06-28
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: -0.1934
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.6524
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step - loss: -0.7295
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step - loss: -0.7295
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - loss: -0.7295
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step - loss: -0.7295
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step - loss: -0.7295
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - loss: -0.7295
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step - loss: -0.7295
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step - loss: -0.7295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.1510 (15.10%)
#
# ==============================
#
# --- Rebalancing 19/23 ---
# Rebalance Date: 2024-07-01
# Training period: 2021-06-25 to 2024-06-28
# Training days: 757
# Test period: 2024-07-01 to 2024-09-27
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: -0.2657
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step - loss: -1.0832
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 793ms/step - loss: -1.1220
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step - loss: -1.1220
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - loss: -1.1220
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - loss: -1.1220
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step - loss: -1.1220
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - loss: -1.1220
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - loss: -1.1220
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - loss: -1.1220
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.2312 (23.12%)
#
# ==============================
#
# --- Rebalancing 20/23 ---
# Rebalance Date: 2024-10-01
# Training period: 2021-09-27 to 2024-09-30
# Training days: 757
# Test period: 2024-10-01 to 2024-12-30
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: -0.3404
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.1249
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step - loss: -1.2873
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step - loss: -1.2873
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step - loss: -1.2873
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step - loss: -1.2873
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step - loss: -1.2873
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - loss: -1.2873
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step - loss: -1.2873
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.2873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: -0.0184 (-1.84%)
#
# ==============================
#
# --- Rebalancing 21/23 ---
# Rebalance Date: 2025-01-02
# Training period: 2021-12-28 to 2024-12-31
# Training days: 757
# Test period: 2025-01-02 to 2025-04-03
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - loss: -0.3463
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.2504
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step - loss: -1.4784
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.4785
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step - loss: -1.4785
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 775ms/step - loss: -1.4785
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 800ms/step - loss: -1.4785
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step - loss: -1.4785
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - loss: -1.4785
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - loss: -1.4785
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 886ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0403 (4.03%)
#
# ==============================
#
# --- Rebalancing 22/23 ---
# Rebalance Date: 2025-04-01
# Training period: 2022-03-24 to 2025-03-31
# Training days: 757
# Test period: 2025-04-01 to 2025-07-01
# Test days: 63
# Training data shape: (757, 59)
# Test returns shape: (63, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: -0.2981
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: -0.6851
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step - loss: -0.5572
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.1422
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step - loss: -1.3932
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step - loss: -1.3932
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step - loss: -1.3919
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - loss: -1.3930
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - loss: -1.2522
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step - loss: -0.5767
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.1640 (16.40%)
#
# ==============================
#
# --- Rebalancing 23/23 ---
# Rebalance Date: 2025-07-01
# Training period: 2022-06-23 to 2025-06-30
# Training days: 757
# Test period: 2025-07-01 to 2025-07-25
# Test days: 18
# Training data shape: (757, 59)
# Test returns shape: (18, 59)
# === Calculating weights with lkbk=252, ep=10, patience=10, PE_type=tAPE, loss_type=maximize_return ===
# Compiling model with Maximize Return Loss.
# X shape: (1, 505, 14868)
# y shape: 10
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - loss: -0.2960
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.7863
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -0.7936
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: -1.2643
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: -1.3686
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: -0.1107
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: -1.3681
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step - loss: -1.3685
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step - loss: -1.3685
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - loss: -1.3685
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step
# Raw Weights selected ETF: 59
# Solving MIP with ECOS_BB...
#
# ==============================
# Total weight: 1.0000 ✅
# Selected ETF count: 59
# Asset Type Allocation:
#   Unknown: 1.000 (100.00%) [Range: 0.00-1.00] ✅
# Quarter return: 0.0410 (4.10%)
#
# ==============================
#
# === Rebalancing Summary ===
# Total quarters processed: 23
# Total return periods: 1404
# Average quarterly return: 0.0848
# Quarterly return std: 0.1171

# %%
rebalance_dates =  get_rebalance_dates(data, start_year=start_rebalance_year)

# add rebalance_dates to weights_df index
weights_df = model_weights.copy()
weights_df.index = rebalance_dates[:len(weights_df)]
print("\n%Weights DataFrame with Rebalance Dates:")
display(weights_df.multiply(100))
# Out:
# Rebalance Dates: ['2020-01-02', '2020-04-01', '2020-07-01', '2020-10-01', '2021-01-04', '2021-04-01', '2021-07-01', '2021-10-01', '2022-01-03', '2022-04-01', '2022-07-01', '2022-10-03', '2023-01-03', '2023-04-03', '2023-07-03', '2023-10-02', '2024-01-02', '2024-04-01', '2024-07-01', '2024-10-01', '2025-01-02', '2025-04-01', '2025-07-01']
#
# %Weights DataFrame with Rebalance Dates:
#                     AAPL           AMD          AMZN          ASML  \
# 2020-01-02  1.000059e+01  3.000000e+01  3.574622e-09  7.106708e-09
# 2020-04-01  2.999922e+01  3.000000e+01  1.359425e-09  2.200950e-09
# 2020-07-01 -7.666533e-05 -6.948720e-06  2.885620e-03 -2.173385e-05
# 2020-10-01  2.722016e-08  2.719026e-08  2.745400e-08  2.731797e-08
# 2021-01-04  2.011601e-09  2.999998e+01  1.687784e-09  1.654024e-09
# 2021-04-01  2.162882e-08  2.177877e-08  2.164752e-08  2.220104e-08
# 2021-07-01  1.028019e-08  9.899321e-09  1.005355e-08  2.993622e+01
# 2021-10-01  2.861294e-08  1.767844e-08  1.824480e-08  1.865065e-08
# 2022-01-03  5.307316e-09  8.187928e-09  3.791583e-09  2.999140e+01
# 2022-04-01  1.341905e-08  1.495667e-08  1.170390e-08  1.822785e-08
# 2022-07-01  3.306815e-09  3.111661e-09  2.584863e-09  3.011618e-09
# 2022-10-03  2.998876e+01  1.096173e-09  1.188538e-09  1.140575e-09
# 2023-01-03  1.212030e-08  1.215438e-08  1.211890e-08  1.419737e-08
# 2023-04-03  2.103903e-08  2.063068e-08  2.153794e-08  2.843966e-08
# 2023-07-03  6.350897e-09  6.347790e-09  6.509746e-09  6.323974e-09
# 2023-10-02  3.787644e-09  3.663753e-09  3.807865e-09  3.816560e-09
# 2024-01-02  2.644133e-08  2.671654e-08  2.659715e-08  2.658412e-08
# 2024-04-01  2.838102e-09  5.716759e-09  2.508632e-09  3.344399e-09
# 2024-07-01  3.275657e-08  3.278432e-08  3.287535e-08  3.279646e-08
# 2024-10-01  1.925033e-08  2.997021e+01  1.950904e-08  1.959851e-08
# 2025-01-02  3.629120e-09  3.730545e-09  3.712706e-09  3.721876e-09
# 2025-04-01  3.613243e-08  3.729157e-08  5.494309e-08  6.158176e-08
# 2025-07-01 -1.156237e-05 -4.071371e-05 -2.045408e-05 -9.962024e-06
#
#                     AVGO           AZN          COST          CSCO  \
# 2020-01-02  1.393535e-08  1.522184e-08  2.999959e+01  3.761063e-09
# 2020-04-01  1.302029e-09  1.874152e-09  1.204527e-09  1.112194e-09
# 2020-07-01 -4.227559e-05 -1.660133e-05 -2.200852e-05  2.053285e+00
# 2020-10-01  2.727247e-08  2.721449e-08  2.778815e-08  2.725184e-08
# 2021-01-04  1.515998e-09  1.195169e-09  2.126150e-09  1.329070e-09
# 2021-04-01  2.182671e-08  2.158771e-08  2.157919e-08  2.163476e-08
# 2021-07-01  9.947135e-09  9.969275e-09  9.922213e-09  9.904316e-09
# 2021-10-01  2.009708e-08  1.875570e-08  2.415006e-08  3.879525e-08
# 2022-01-03  2.999968e+01  2.827207e-09  7.888914e-09  2.944523e-09
# 2022-04-01  1.157177e-08  1.392076e-08  1.393818e-08  1.216743e-08
# 2022-07-01  2.713002e-09  2.700342e-09  2.644715e-09  2.584457e-09
# 2022-10-03  1.029376e-09  9.462173e-10  1.073930e-09  1.024998e-09
# 2023-01-03  1.252657e-08  1.215017e-08  1.219757e-08  1.227197e-08
# 2023-04-03  2.417472e-08  2.328699e-08  2.068508e-08  2.601176e-08
# 2023-07-03  6.404947e-09  6.362996e-09  6.334655e-09  6.360144e-09
# 2023-10-02  4.144510e-09  3.746709e-09  3.657448e-09  3.639809e-09
# 2024-01-02  2.639661e-08  2.635274e-08  2.639057e-08  2.631595e-08
# 2024-04-01  2.512570e-09  2.742681e-09  2.502797e-09  2.838676e-09
# 2024-07-01  3.274155e-08  3.274292e-08  3.281310e-08  3.274570e-08
# 2024-10-01  2.059700e-08  1.927271e-08  1.927246e-08  1.931847e-08
# 2025-01-02  3.657398e-09  3.965864e-09  4.700307e-09  3.668319e-09
# 2025-04-01  3.630839e-07  4.071833e-08  7.518845e-08  4.710117e-08
# 2025-07-01  1.113345e-03 -9.967574e-06 -2.381666e-05 -2.107164e-05
#
#                     GOOG         GOOGL  ...           SAP          SHEL  \
# 2020-01-02  2.656729e-09  2.318256e-09  ...  2.472768e-09  2.146264e-09
# 2020-04-01  1.241156e-09  1.838662e-09  ...  1.218694e-09  1.042412e-09
# 2020-07-01 -3.283933e-05 -1.649094e-05  ... -1.663001e-05 -1.495895e-05
# 2020-10-01  2.737674e-08  2.732854e-08  ...  2.284961e+01  2.727938e-08
# 2021-01-04  1.356955e-09  1.431212e-09  ...  1.312191e-09  1.167261e-09
# 2021-04-01  2.253738e-08  2.195244e-08  ...  2.166742e-08  2.164098e-08
# 2021-07-01  1.052484e-08  1.049842e-08  ...  9.925659e-09  9.993381e-09
# 2021-10-01  1.865448e-08  1.944058e-08  ...  1.902582e-08  1.837153e-08
# 2022-01-03  4.422085e-09  6.842154e-09  ...  3.119003e-09  2.602426e-09
# 2022-04-01  1.565970e-08  2.999412e+01  ...  1.292215e-08  1.259374e-08
# 2022-07-01  3.029162e-09  2.665546e-09  ...  2.600496e-09  2.840038e-09
# 2022-10-03  1.001125e+01  1.029157e-09  ...  1.035292e-09  1.020723e-09
# 2023-01-03  1.215062e-08  1.237685e-08  ...  1.222397e-08  2.999941e+01
# 2023-04-03  2.150756e-08  2.210322e-08  ...  2.448513e-08  2.422168e-08
# 2023-07-03  6.352024e-09  6.349416e-09  ...  6.343628e-09  2.487598e+01
# 2023-10-02  3.645749e-09  3.718249e-09  ...  3.748160e-09  3.631083e-09
# 2024-01-02  2.630538e-08  2.653479e-08  ...  2.636222e-08  2.631321e-08
# 2024-04-01  2.867681e-09  2.935681e-09  ...  3.110811e-09  3.160701e-09
# 2024-07-01  3.274626e-08  3.281317e-08  ...  3.291308e-08  3.282876e-08
# 2024-10-01  1.944964e-08  1.928686e-08  ...  1.965784e-08  1.926968e-08
# 2025-01-02  4.028151e-09  3.704710e-09  ...  1.000197e+01  3.639729e-09
# 2025-04-01  9.535722e-08  5.243185e-08  ...  4.059131e-08  8.338684e-07
# 2025-07-01 -1.177763e-05 -9.981108e-06  ... -9.844686e-06 -1.004843e-05
#
#                        T            TM           TSM           UNH  \
# 2020-01-02  3.139307e-09  2.358030e-09  1.065378e-08  2.839721e-09
# 2020-04-01  1.674206e-09  1.077395e-09  1.091049e-09  1.069788e-09
# 2020-07-01 -1.689721e-05 -1.565877e-05 -3.952083e-05 -2.407137e-05
# 2020-10-01  2.739538e-08  2.739427e-08  2.739544e-08  2.751765e-08
# 2021-01-04  1.265169e-09  1.373829e-09  1.694110e-09  1.968185e-09
# 2021-04-01  2.162889e-08  2.178078e-08  2.204969e-08  2.169571e-08
# 2021-07-01  9.950966e-09  9.903513e-09  1.009146e-08  1.013459e-08
# 2021-10-01  1.899279e-08  1.813038e-08  2.999962e+01  1.851742e-08
# 2022-01-03  2.606418e-09  2.663516e-09  5.267898e-09  7.117849e-09
# 2022-04-01  1.205199e-08  1.216000e-08  1.188239e-08  2.063914e-08
# 2022-07-01  2.588088e-09  2.606329e-09  2.599346e-09  2.660436e-09
# 2022-10-03  9.798054e-10  1.273422e-09  1.043641e-09  1.262622e-09
# 2023-01-03  1.209757e-08  1.217110e-08  1.218257e-08  2.840803e-08
# 2023-04-03  2.155069e-08  2.264678e-08  2.089339e-08  2.162206e-08
# 2023-07-03  6.385207e-09  6.336104e-09  6.360016e-09  2.975287e+01
# 2023-10-02  3.633290e-09  3.719163e-09  3.692837e-09  3.754240e-09
# 2024-01-02  2.636728e-08  2.631959e-08  2.644577e-08  2.635544e-08
# 2024-04-01  3.137375e-09  2.556944e-09  2.829442e-09  2.843097e-09
# 2024-07-01  3.274341e-08  3.274616e-08  3.289275e-08  3.276499e-08
# 2024-10-01  1.931764e-08  1.928382e-08  1.932298e-08  1.926546e-08
# 2025-01-02  3.861968e-09  3.911611e-09  3.655363e-09  3.682276e-09
# 2025-04-01  4.621322e-08  3.752417e-08  4.157202e-08  1.348462e-07
# 2025-07-01 -1.307971e-04 -2.778980e-05 -8.488016e-05  2.014341e+00
#
#                        V           WFC           WMT           XOM
# 2020-01-02  1.160249e-08  2.145097e-09  7.327987e-09  2.949361e-09
# 2020-04-01  1.593795e-09  1.059226e-09  1.468151e-09  1.152226e-09
# 2020-07-01 -2.595049e-05  2.859851e+00 -3.874706e-05 -1.635790e-05
# 2020-10-01  2.722646e-08  2.720311e-08  2.769547e-08  2.723548e-08
# 2021-01-04  1.345674e-09  1.290476e-09  1.326603e-09  1.374902e-09
# 2021-04-01  2.160573e-08  2.157962e-08  2.160719e-08  2.157948e-08
# 2021-07-01  1.012927e-08  9.906336e-09  1.007250e-08  9.899686e-09
# 2021-10-01  1.905591e-08  1.939051e-08  1.000456e+01  1.986498e-08
# 2022-01-03  3.265011e-09  2.944587e-09  4.236501e-09  2.724810e-09
# 2022-04-01  1.307158e-08  1.178427e-08  1.170002e-08  2.999978e+01
# 2022-07-01  2.606914e-09  1.000699e+01  2.660937e-09  2.612427e-09
# 2022-10-03  1.795903e-09  1.037664e-09  9.693451e-10  2.999999e+01
# 2023-01-03  1.214571e-08  1.215286e-08  1.292097e-08  2.999016e+01
# 2023-04-03  2.233407e-08  2.110089e-08  2.504045e-08  2.999926e+01
# 2023-07-03  6.348030e-09  6.437831e-09  6.320978e-09  6.357779e-09
# 2023-10-02  3.832469e-09  4.005073e-09  4.561458e-09  3.795903e-09
# 2024-01-02  2.635411e-08  2.644487e-08  2.633207e-08  2.663534e-08
# 2024-04-01  3.760189e-09  2.550300e-09  2.520019e-09  2.926043e-09
# 2024-07-01  3.292023e-08  3.275025e-08  3.295557e-08  3.275790e-08
# 2024-10-01  1.931070e-08  1.934770e-08  1.930559e-08  1.927794e-08
# 2025-01-02  3.624642e-09  3.735802e-09  3.656495e-09  3.617470e-09
# 2025-04-01  3.709444e-08  3.649853e-08  4.102623e-08  4.158927e-08
# 2025-07-01 -1.466811e-05 -1.474445e-05 -1.146743e-05  1.151021e+01
#
# [23 rows x 59 columns]

# %%
raw_weights_df = Model_raw_weights.copy()
raw_weights_df.index = rebalance_dates[:len(raw_weights_df)]


# print("\n%Raw Weights DataFrame with Rebalance Dates:")
# display(raw_weights_df.multiply(100).round(4))

# %%
# # --- Run the Check and Print Results ---
# violations_found = check_portfolio_constraints(
#     weights_df, 
#     asset_map, 
#     asset_lower_aggressive, 
#     asset_upper_aggressive
# )

# if not violations_found:
#     print("✅ All portfolio weights satisfy the constraints.")
# else:
#     print("❌ Constraint violations were found:")
#     for date, messages in violations_found.items():
#         print(f"\nOn {date}:")
#         for msg in messages:
#             print(f"  - {msg}")

# %%
# weights_df.to_csv(f'{output_dir}/{train_type}/raw_weights_df_run{run_no}.csv', index=True)

save_dataframe_to_new_sheet(raw_weights_df, results_excel_path, 'Weights_Before_PostNorm')
save_dataframe_to_new_sheet(weights_df, results_excel_path, 'Weights_After_PostNorm')
# Out:
# DataFrame saved to sheet 'Weights_Before_PostNorm' in new file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx ✨
# DataFrame saved to sheet 'Weights_After_PostNorm' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %%
# os.system('say "Model training has finished"')

# %% [markdown]
# # Compared

# %% [markdown]
# ### 1. Model weights

# %%
model_weights_df = weights_df.copy()
model_weights_df = model_weights_df.round(4)
model_weights_df = model_weights_df.abs()
model_weights_df
save_dataframe_to_new_sheet(model_weights_df, results_excel_path, 'Model Weights')
# model_weights_df
# Out:
# DataFrame saved to sheet 'Model Weights' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %%
# check number of weights > 0 in each row
non_zero_weights_count = (model_weights_df > 0).sum(axis=1)
print("\nNumber of non-zero weights in each row:")
print(non_zero_weights_count)
# Out:
# Number of non-zero weights in each row:
# 2020-01-02     4
# 2020-04-01     4
# 2020-07-01    10
# 2020-10-01     4
# 2021-01-04     4
# 2021-04-01     4
# 2021-07-01     4
# 2021-10-01     4
# 2022-01-03     4
# 2022-04-01     4
# 2022-07-01     4
# 2022-10-03     4
# 2023-01-03     4
# 2023-04-03     4
# 2023-07-03     4
# 2023-10-02     4
# 2024-01-02     4
# 2024-04-01     4
# 2024-07-01     4
# 2024-10-01     4
# 2025-01-02     4
# 2025-04-01     4
# 2025-07-01    10
# dtype: int64

# %%
# check total weight in each row to ensure it sums to 1
total_weights = model_weights_df.sum(axis=1).round(2)
print("\nTotal weights in each row (should be 1):")
print(total_weights)
# Out:
# Total weights in each row (should be 1):
# 2020-01-02    1.0
# 2020-04-01    1.0
# 2020-07-01    1.0
# 2020-10-01    1.0
# 2021-01-04    1.0
# 2021-04-01    1.0
# 2021-07-01    1.0
# 2021-10-01    1.0
# 2022-01-03    1.0
# 2022-04-01    1.0
# 2022-07-01    1.0
# 2022-10-03    1.0
# 2023-01-03    1.0
# 2023-04-03    1.0
# 2023-07-03    1.0
# 2023-10-02    1.0
# 2024-01-02    1.0
# 2024-04-01    1.0
# 2024-07-01    1.0
# 2024-10-01    1.0
# 2025-01-02    1.0
# 2025-04-01    1.0
# 2025-07-01    1.0
# dtype: float64

# %%
model_weights_df.iloc[-1].sort_values(ascending=False).plot(kind='bar', figsize=(12, 6), title='MVO Weights at Last Rebalance Date')
# Out:
# <Axes: title={'center': 'MVO Weights at Last Rebalance Date'}>

# %% [markdown]
# ### 2. Traditional mean-variance optimization

# %%
def mvo_quarterly_mip_rebalancing(data, port_type, 
                                  start_year=2020, trading_days_per_quarter=63, 
                                  min_train_periods=252, risk_aversion=1.0,
                                  min_assets=2, max_assets=10, min_weight_per_asset=0.01):
    """
    คำนวณ MVO แบบ Quarterly Rebalancing โดยใช้ MIP พร้อมบังคับเงื่อนไขที่เข้มงวด:
    - จำนวนสินทรัพย์ในพอร์ตต้องอยู่ระหว่าง min_assets และ max_assets เท่านั้น
    - สินทรัพย์ที่ถูกเลือก ต้องมีน้ำหนักอย่างน้อย min_weight_per_asset
    """
    weights_dict = {}
    asset_symbols = list(data.columns)
    
    rebalance_dates = get_rebalance_dates(data, start_year)
    original_index = data.index.copy()
    df_reset = data.copy()
    df_reset.index = range(len(df_reset))

    for i, rebalance_date in enumerate(rebalance_dates):
        print(f"\n--- MVO-MIP Rebalancing {i+1}/{len(rebalance_dates)} ---")
        print(f"Rebalance Date: {rebalance_date.strftime('%Y-%m-%d')}")
        
        try:
            train_end_pos = original_index.get_loc(rebalance_date) - 1
        except KeyError:
            nearest_dates = original_index[original_index >= rebalance_date]
            if len(nearest_dates) == 0: continue
            train_end_pos = original_index.get_loc(nearest_dates[0])
        
        train_start_pos = max(0, train_end_pos - min_train_periods)
        print(f"Training period: {original_index[train_start_pos].strftime('%Y-%m-%d')} to {original_index[train_end_pos].strftime('%Y-%m-%d')}")
        
        lookback_data = df_reset.iloc[train_start_pos:train_end_pos+1].copy().ffill().bfill()
        
        if len(lookback_data) < 50:
            print(f"❌ Insufficient data for {rebalance_date}")
            continue
            
        try:
            mu = expected_returns.mean_historical_return(lookback_data).values
            S = risk_models.sample_cov(lookback_data).values
        except Exception as e:
            print(f"❌ Could not calculate returns/covariance: {e}")
            continue

        n_assets = len(asset_symbols)
        
        # 1. กำหนดตัวแปร
        w = cp.Variable(n_assets, name='weights')
        b = cp.Variable(n_assets, boolean=True, name='selection')

        # 2. กำหนด Objective Function
        objective = cp.Maximize(w.T @ mu - risk_aversion * cp.quad_form(w, S))

        # 3. กำหนด Constraints
        constraints = [
            cp.sum(w) == 1,
            w >= 0, # สำหรับ Long-Only
            
            # === ส่วนสำคัญที่แก้ไข ===
            # บังคับจำนวนหุ้นที่เลือก (b=1)
            cp.sum(b) >= min_assets,
            cp.sum(b) <= max_assets,
            
            # เชื่อมโยง w และ b (Big-M Method)
            # 1. ถ้าไม่เลือก (b=0) -> w ต้องเป็น 0
            #    (w <= 1.0*b, ถ้า b=0 -> w<=0, และ w>=0 ดังนั้น w=0)
            w <= 1.0 * b,
            
            # 2. ถ้าเลือก (b=1) -> w ต้องมีค่าอย่างน้อย min_weight_per_asset
            #    (w >= min_weight * b, ถ้า b=1 -> w>=min_weight)
            w >= min_weight_per_asset * b
        ]

        # 4. แก้ปัญหา
        problem = cp.Problem(objective, constraints)
        try:
            problem.solve(solver=cp.ECOS_BB, verbose=False)
        except Exception as e:
            print(f"❌ Optimization failed: {e}")
            continue
            
        if w.value is not None and problem.status in [cp.OPTIMAL, cp.OPTIMAL_INACCURATE]:
            # ทำความสะอาด weight ที่มีค่าน้อยมากๆ (เผื่อไว้ แต่ไม่น่าจำเป็นแล้ว)
            cleaned_weights = {asset: w_val if w_val > 1e-6 else 0 for asset, w_val in zip(asset_symbols, w.value)}
            # Normalize เพื่อให้ผลรวมเป็น 1.0 พอดี
            total_w = sum(cleaned_weights.values())
            if total_w > 0:
                final_weights = {asset: w_val / total_w for asset, w_val in cleaned_weights.items()}
            else:
                final_weights = cleaned_weights
            
            weights_dict[rebalance_date] = final_weights
            num_assets_selected = sum(1 for v in final_weights.values() if v > 0)
            print(f"✅ Optimization successful. Selected {num_assets_selected} assets.")
        else:
            print(f"❌ Solver could not find an optimal solution. Status: {problem.status}")
            continue
    
    optimal_weights_df = pd.DataFrame.from_dict(weights_dict, orient='index')
    optimal_weights_df = optimal_weights_df.reindex(columns=data.columns, fill_value=0)
    
    return optimal_weights_df

# %%
# risk_free = 0.02  # Example risk-free rate
# mvo_weights_df = mvo_quarterly_mip_rebalancing(data, port_type, start_year=start_rebalance_year,
#                                            trading_days_per_quarter=n_trading_days_per_quarter,
#                                            min_train_periods=n_min_train_periods,
#                                            risk_free_rate=risk_free)

# mvo_weights_df = mvo_weights_df.round(4)
# save_dataframe_to_new_sheet(mvo_weights_df, results_excel_path, 'MVO Weights')
# # mvo_weights_df

# Cell ที่ [cb3ea45e]
# risk_free = 0.02 # ไม่ต้องใช้แล้ว เพราะเราใช้ risk_aversion แทน
risk_aversion_param = 1.0 # สามารถปรับค่านี้ได้ ยิ่งมากยิ่งเน้นลดความเสี่ยง

# เปลี่ยนชื่อฟังก์ชันที่เรียก
mvo_weights_df = mvo_quarterly_mip_rebalancing(data, port_type, start_year=start_rebalance_year,
                                               trading_days_per_quarter=n_trading_days_per_quarter,
                                               min_train_periods=n_min_train_periods,
                                               risk_aversion=risk_aversion_param)

mvo_weights_df = mvo_weights_df.round(4)
save_dataframe_to_new_sheet(mvo_weights_df, results_excel_path, 'MVO Weights')
# mvo_weights_df
# Out:
# Rebalance Dates: ['2020-01-02', '2020-04-01', '2020-07-01', '2020-10-01', '2021-01-04', '2021-04-01', '2021-07-01', '2021-10-01', '2022-01-03', '2022-04-01', '2022-07-01', '2022-10-03', '2023-01-03', '2023-04-03', '2023-07-03', '2023-10-02', '2024-01-02', '2024-04-01', '2024-07-01', '2024-10-01', '2025-01-02', '2025-04-01', '2025-07-01']
#
# --- MVO-MIP Rebalancing 1/23 ---
# Rebalance Date: 2020-01-02
# Training period: 2016-12-28 to 2019-12-31
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 2/23 ---
# Rebalance Date: 2020-04-01
# Training period: 2017-03-29 to 2020-03-31
# ✅ Optimization successful. Selected 3 assets.
#
# --- MVO-MIP Rebalancing 3/23 ---
# Rebalance Date: 2020-07-01
# Training period: 2017-06-28 to 2020-06-30
# ✅ Optimization successful. Selected 3 assets.
#
# --- MVO-MIP Rebalancing 4/23 ---
# Rebalance Date: 2020-10-01
# Training period: 2017-09-28 to 2020-09-30
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 5/23 ---
# Rebalance Date: 2021-01-04
# Training period: 2017-12-29 to 2020-12-31
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 6/23 ---
# Rebalance Date: 2021-04-01
# Training period: 2018-03-29 to 2021-03-31
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 7/23 ---
# Rebalance Date: 2021-07-01
# Training period: 2018-06-28 to 2021-06-30
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 8/23 ---
# Rebalance Date: 2021-10-01
# Training period: 2018-09-28 to 2021-09-30
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 9/23 ---
# Rebalance Date: 2022-01-03
# Training period: 2019-01-02 to 2021-12-31
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 10/23 ---
# Rebalance Date: 2022-04-01
# Training period: 2019-04-02 to 2022-03-31
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 11/23 ---
# Rebalance Date: 2022-07-01
# Training period: 2019-07-01 to 2022-06-30
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 12/23 ---
# Rebalance Date: 2022-10-03
# Training period: 2019-10-01 to 2022-09-30
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 13/23 ---
# Rebalance Date: 2023-01-03
# Training period: 2019-12-31 to 2022-12-30
# ✅ Optimization successful. Selected 3 assets.
#
# --- MVO-MIP Rebalancing 14/23 ---
# Rebalance Date: 2023-04-03
# Training period: 2020-03-31 to 2023-03-31
# ✅ Optimization successful. Selected 3 assets.
#
# --- MVO-MIP Rebalancing 15/23 ---
# Rebalance Date: 2023-07-03
# Training period: 2020-06-29 to 2023-06-30
# ✅ Optimization successful. Selected 4 assets.
#
# --- MVO-MIP Rebalancing 16/23 ---
# Rebalance Date: 2023-10-02
# Training period: 2020-09-28 to 2023-09-29
# ✅ Optimization successful. Selected 3 assets.
#
# --- MVO-MIP Rebalancing 17/23 ---
# Rebalance Date: 2024-01-02
# Training period: 2020-12-28 to 2023-12-29
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 18/23 ---
# Rebalance Date: 2024-04-01
# Training period: 2021-03-26 to 2024-03-28
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 19/23 ---
# Rebalance Date: 2024-07-01
# Training period: 2021-06-25 to 2024-06-28
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 20/23 ---
# Rebalance Date: 2024-10-01
# Training period: 2021-09-27 to 2024-09-30
# ✅ Optimization successful. Selected 2 assets.
#
# --- MVO-MIP Rebalancing 21/23 ---
# Rebalance Date: 2025-01-02
# Training period: 2021-12-28 to 2024-12-31
# ✅ Optimization successful. Selected 4 assets.
#
# --- MVO-MIP Rebalancing 22/23 ---
# Rebalance Date: 2025-04-01
# Training period: 2022-03-24 to 2025-03-31
# ✅ Optimization successful. Selected 3 assets.
#
# --- MVO-MIP Rebalancing 23/23 ---
# Rebalance Date: 2025-07-01
# Training period: 2022-06-23 to 2025-06-30
# ✅ Optimization successful. Selected 3 assets.
# DataFrame saved to sheet 'MVO Weights' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %%
mvo_weights_df.iloc[-1].sort_values(ascending=False).plot(kind='bar', figsize=(12, 6), title='MVO Weights at Last Rebalance Date')
# Out:
# <Axes: title={'center': 'MVO Weights at Last Rebalance Date'}>

# %%
# # --- Run the Check and Print Results ---
# violations_found = check_portfolio_constraints(
#     mvo_weights_df, 
#     asset_map, 
#     asset_lower_aggressive, 
#     asset_upper_aggressive
# )

# if not violations_found:
#     print("✅ All portfolio weights satisfy the constraints.")
# else:
#     print("❌ Constraint violations were found:")
#     for date, messages in violations_found.items():
#         print(f"\nOn {date}:")
#         for msg in messages:
#             print(f"  - {msg}")

# # check number of weights > 0 in each row
# non_zero_weights_count = (mvo_weights_df > 0).sum(axis=1)
# print("\nNumber of non-zero weights in each row:")
# print(non_zero_weights_count)

# # check total weight in each row to ensure it sums to 1
# total_weights = mvo_weights_df.sum(axis=1).round(2)
# print("\nTotal weights in each row (should be 1):")
# print(total_weights)

# %% [markdown]
# ### 3. Equal weights

# %%
# Run equal weight portfolio
equal_weights_df = equal_weight_portfolio(data, rebalance_dates)
equal_weights_df = equal_weights_df.round(4)
save_dataframe_to_new_sheet(equal_weights_df, results_excel_path, 'Equal Weights')
# equal_weights_df
# Out:
# DataFrame saved to sheet 'Equal Weights' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %% [markdown]
# ### 4. Benchmark

# %%
benchmark_list = ['DIA']
benchmark_data = getData(benchmark_list, startDate, endDate)
benchmark_data.fillna(method='ffill', inplace=True)

benchmark_df = pd.DataFrame(
   index=rebalance_dates,
    columns=benchmark_list,
   data=0.0
)
benchmark_df['DIA'] = 1.0

save_dataframe_to_new_sheet(benchmark_df, results_excel_path, 'Beanchmark Weights')
# benchmark_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# DataFrame saved to sheet 'Beanchmark Weights' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %% [markdown]
# ### 4. Compared

# %%
# Main analysis
start_date = rebalance_dates[0]  # First rebalance date

# Calculate portfolio returns for each strategy
portfolios = {
    'Model Portfolio': model_weights_df,
    'MVO Portfolio': mvo_weights_df,
    'Equal Weight': equal_weights_df,
    'Benchmark': benchmark_df
}

portfolio_returns = {}
for name, weights in portfolios.items():
    returns = calculate_portfolio_returns(data, weights, rebalance_dates, start_date)
    portfolio_returns[name] = returns

benchmark_returns = calculate_portfolio_returns(benchmark_data, benchmark_df, rebalance_dates, start_date)
portfolio_returns['Benchmark'] = benchmark_returns

# Calculate performance metrics
performance_metrics = {}
benchmark_returns = portfolio_returns['Benchmark']

for name, returns in portfolio_returns.items():
    if name == 'Benchmark':
        metrics = calculate_performance_metrics(returns, returns)  # Self as benchmark
    else:
        metrics = calculate_performance_metrics(returns, benchmark_returns)
    performance_metrics[name] = metrics

# Create performance comparison DataFrame
performance_df = pd.DataFrame(performance_metrics).T
print("Portfolio Performance Comparison:")
print("=" * 50)
# performance_df.to_csv(f'{output_dir}/{train_type}/performance_comparison_run{run_no}.csv')
save_dataframe_to_new_sheet(performance_df.T, results_excel_path, 'Performance Comparison')
performance_df.round(4).T
# Out:
# Portfolio Performance Comparison:
# ==================================================
# DataFrame saved to sheet 'Performance Comparison' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/01_Results_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
#                               Model Portfolio  MVO Portfolio  Equal Weight  \
# Total Return (%)                     403.9726       212.8706      210.0141
# Annualized Return (%)                 33.8487        22.8268       22.6239
# Volatility (%)                        32.8838        45.5318       20.1958
# Sharpe Ratio                           0.9904         0.6361        1.0125
# Max Drawdown (%)                     -29.8907       -73.3145      -30.8555
# Max Drawdown Duration (days)         415.0000       919.0000      320.0000
# Sortino Ratio                          1.4031         0.8475        1.2373
# Treynor Ratio                          0.3156         0.2521        0.2188
# Jensen's Alpha (%)                    22.2989        17.5267       11.1476
# Beta                                   1.0319         1.1489        0.9346
# R-squared                              0.4175         0.2700        0.9079
# Tracking Error (%)                    25.1049        39.0228        6.2791
# Information Ratio                      0.9009         0.4871        1.6716
# Value at Risk (VaR) (%)               -3.1558        -4.8963       -1.7420
#
#                               Benchmark
# Total Return (%)                72.3976
# Annualized Return (%)           10.3155
# Volatility (%)                  20.6055
# Sharpe Ratio                     0.4830
# Max Drawdown (%)               -36.6982
# Max Drawdown Duration (days)   477.0000
# Sortino Ratio                    0.5768
# Treynor Ratio                    0.0995
# Jensen's Alpha (%)              -0.0071
# Beta                             1.0007
# R-squared                        1.0000
# Tracking Error (%)               0.0000
# Information Ratio                   NaN
# Value at Risk (VaR) (%)         -1.7202

# %%
# Plotting
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=('Cumulative Returns', 'Maximum Drawdown'),
    vertical_spacing=0.12,
    row_heights=[0.7, 0.3]
)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Plot cumulative returns
for i, (name, returns) in enumerate(portfolio_returns.items()):
    #if name != 'Benchmark':
    cumulative_returns = (1 + returns).cumprod()
    fig.add_trace(
        go.Scatter(
            x=cumulative_returns.index,
            y=cumulative_returns.values,
            mode='lines',
            name=name,
            line=dict(color=colors[i], width=2),
            showlegend=True
        ),
        row=1, col=1
    )

# Plot drawdowns
for i, (name, returns) in enumerate(portfolio_returns.items()):
#if name != 'Benchmark':
    cumulative = (1 + returns).cumprod()
    rolling_max = cumulative.expanding().max()
    drawdown = (cumulative - rolling_max) / rolling_max * 100
    
    fig.add_trace(
        go.Scatter(
            x=drawdown.index,
            y=drawdown.values,
            mode='lines',
            name=name,
            line=dict(color=colors[i], width=2),
            showlegend=False
        ),
        row=2, col=1
    )

# Update layout
fig.update_layout(
    title='Portfolio Performance Comparison',
    height=800,
    hovermode='x unified',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

fig.update_xaxes(title_text="Date", row=2, col=1)
fig.update_yaxes(title_text="Cumulative Return", row=1, col=1)
fig.update_yaxes(title_text="Drawdown (%)", row=2, col=1)

fig.show()

# Save the plot to a file
fig.write_html(f'{output_dir}/{train_type}/portfolio_performance_{model_type}_run_{run_no}.html')
# save image to file
fig.write_image(f'{output_dir}/{train_type}/portfolio_performance_{model_type}_run_{run_no}.png')

# %%
# Summary statistics
print("\nKey Performance Highlights:")
print("=" * 30)

best_return = performance_df['Annualized Return (%)'].idxmax()
print(f"Best Annualized Return: {best_return} ({performance_df.loc[best_return, 'Annualized Return (%)']:.2f}%)")

best_sharpe = performance_df['Sharpe Ratio'].idxmax()
print(f"Best Sharpe Ratio: {best_sharpe} ({performance_df.loc[best_sharpe, 'Sharpe Ratio']:.3f})")

best_sortino = performance_df['Sortino Ratio'].idxmax()
print(f"Best Sortino Ratio: {best_sortino} ({performance_df.loc[best_sortino, 'Sortino Ratio']:.3f})")

lowest_dd = performance_df['Max Drawdown (%)'].idxmax()  # Most negative (lowest)
print(f"Lowest Max Drawdown: {lowest_dd} ({performance_df.loc[lowest_dd, 'Max Drawdown (%)']:.2f}%)")

lowest_vol = performance_df['Volatility (%)'].idxmin()
print(f"Lowest Volatility: {lowest_vol} ({performance_df.loc[lowest_vol, 'Volatility (%)']:.2f}%)")
# Out:
# Key Performance Highlights:
# ==============================
# Best Annualized Return: Model Portfolio (33.85%)
# Best Sharpe Ratio: Equal Weight (1.013)
# Best Sortino Ratio: Model Portfolio (1.403)
# Lowest Max Drawdown: Model Portfolio (-29.89%)
# Lowest Volatility: Equal Weight (20.20%)

# %%
# os.system('say "Model comparison has finished"')

# %% [markdown]
# # Quarterly Comparison

# %%
# Get quarterly periods
quarterly_periods = get_quarterly_periods(rebalance_dates, data)
quarterly_periods

# Portfolio definitions
portfolios = {
    'Model Portfolio': model_weights_df,
    'MVO Portfolio': mvo_weights_df,
    'Equal Weight': equal_weights_df,
    'Benchmark': benchmark_df
}

# Calculate quarterly performance for each portfolio
quarterly_results = {}
weights_df_2 = weights_df.copy
for portfolio_name, weights_df_2 in portfolios.items():
    quarterly_results[portfolio_name] = {}
    
    for period in quarterly_periods:
        quarter = period['quarter']
        returns = calculate_quarterly_portfolio_returns(data, weights_df_2, period)
        metrics = calculate_quarterly_metrics(returns)
        quarterly_results[portfolio_name][quarter] = metrics

# Create comprehensive results DataFrame
all_metrics = ['Total Return (%)', 'Annualized Return (%)',
               'Volatility (%)', 'Max Drawdown (%)', 
               'Max Drawdown Duration (days)', 'Sharpe Ratio', 'Sortino Ratio']
quarterly_comparison = {}

for metric in all_metrics:
    quarterly_comparison[metric] = pd.DataFrame({
        portfolio: {quarter: quarterly_results[portfolio][quarter][metric] 
                   for quarter in quarterly_results[portfolio]}
        for portfolio in portfolios.keys()
    })

# Display results
for metric in all_metrics:
    print(f"\n{metric}")
    print("-" * 40)
    print(quarterly_comparison[metric].round(4))
    # quarterly_comparison[metric].to_csv(f'{output_dir}/{train_type}/quarterly_{metric.lower().replace(" ", "_")}_run{run_no}.csv', index=True)
# Out:
# Total Return (%)
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020          -3.9925       -16.6660      -15.9677        0.0
# Q2 2020          29.9183        30.6687       22.5578        0.0
# Q3 2020          -0.3470        15.8876        8.9277        0.0
# Q4 2020          14.2848        27.3884       16.5338        0.0
# Q1 2021          -5.0571       -10.5676        8.9248        0.0
# Q2 2021           1.6500         7.3634        8.4031        0.0
# Q3 2021           7.9318        13.4529        0.4495        0.0
# Q4 2021          20.1651        36.0608        7.2701        0.0
# Q1 2022          -9.5005        -9.8284       -2.7561        0.0
# Q2 2022         -22.0248       -37.9525      -13.5417        0.0
# Q3 2022           0.2473        16.5723       -6.7730        0.0
# Q4 2022           6.6265       -48.7383        9.4047        0.0
# Q1 2023           0.6621        21.7829       11.1570        0.0
# Q2 2023          16.0047        17.0220        9.4193        0.0
# Q3 2023           7.3394         8.9220       -1.3333        0.0
# Q4 2023          10.9571        -1.8358       11.7739        0.0
# Q1 2024          44.4494        43.6416       14.3456        0.0
# Q2 2024          14.7111        31.0811        5.0206        0.0
# Q3 2024          22.1427        -1.4568        8.5519        0.0
# Q4 2024          -1.4399        -1.4865        4.4779        0.0
# Q1 2025           4.6400       -10.2119        2.2580        0.0
# Q2 2025          17.5123        36.0186       10.7403        0.0
# Q3 2025           2.4332        16.4779        2.1968        0.0
#
# Annualized Return (%)
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020         -15.4916       -52.9125      -51.2610        0.0
# Q2 2020         189.7444       196.6067      128.5932        0.0
# Q3 2020          -1.3809        80.3629       40.7839        0.0
# Q4 2020          70.5904       163.3420       84.4201        0.0
# Q1 2021         -19.5839       -37.4428       43.1964        0.0
# Q2 2021           6.8779        33.4801       38.8120        0.0
# Q3 2021          35.7057        65.6768        1.8103        0.0
# Q4 2021         108.5033       242.7142       32.4084        0.0
# Q1 2022         -33.7939       -34.7791      -10.9040        0.0
# Q2 2022         -64.2186       -86.0776      -45.1800        0.0
# Q3 2022           0.9929        84.6637      -24.4619        0.0
# Q4 2022          29.7949       -93.3862       44.0992        0.0
# Q1 2023           2.7637       125.7201       54.8000        0.0
# Q2 2023          84.6536        91.4358       45.0452        0.0
# Q3 2023          33.3585        41.5329       -5.3094        0.0
# Q4 2023          52.5925        -7.2544       57.2098        0.0
# Q1 2024         368.6043       357.6960       75.5991        0.0
# Q2 2024          74.6895       200.4305       22.0313        0.0
# Q3 2024         122.5719        -5.7011       38.8512        0.0
# Q4 2024          -5.6364        -5.8147       19.1510        0.0
# Q1 2025          21.3761       -36.8768       10.0065        0.0
# Q2 2025          94.7708       256.3810       52.4172        0.0
# Q3 2025          42.8137       859.3177       38.0049        0.0
#
# Volatility (%)
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020          60.5023        70.7105       54.6598        0.0
# Q2 2020          33.0318        34.2666       29.1056        0.0
# Q3 2020          26.1566        36.2135       16.0870        0.0
# Q4 2020          26.3036        37.6656       16.3761        0.0
# Q1 2021          52.1927        55.3667       14.2701        0.0
# Q2 2021          18.5986        37.1729       10.0689        0.0
# Q3 2021          16.7787        27.4429       10.9039        0.0
# Q4 2021          21.6390        60.3069       13.2817        0.0
# Q1 2022          47.0325        63.8553       20.4757        0.0
# Q2 2022          45.5053        75.2424       27.5637        0.0
# Q3 2022          27.8263        48.6756       20.3463        0.0
# Q4 2022          24.3083        66.9680       23.0731        0.0
# Q1 2023          22.3739        24.0729       15.1647        0.0
# Q2 2023          21.5605        25.4477       11.3821        0.0
# Q3 2023          15.4360        22.0774       10.8132        0.0
# Q4 2023          19.6961        18.5399       11.8279        0.0
# Q1 2024          22.3134        28.0674        9.6880        0.0
# Q2 2024          28.7099        37.6281        9.2893        0.0
# Q3 2024          36.0101        45.9915       14.2364        0.0
# Q4 2024          23.3951        26.3509       10.8422        0.0
# Q1 2025          47.5313        41.2525       14.9826        0.0
# Q2 2025          43.8231        49.5993       27.5203        0.0
# Q3 2025          12.5058        21.4383        7.6844        0.0
#
# Max Drawdown (%)
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020         -24.9583       -38.0135      -30.8555        0.0
# Q2 2020          -5.4305        -5.6062       -6.5631        0.0
# Q3 2020         -10.5276       -14.4371       -8.0725        0.0
# Q4 2020         -16.3270       -12.7121       -7.7549        0.0
# Q1 2021         -28.8437       -30.0393       -3.5704        0.0
# Q2 2021         -10.8045       -20.0010       -3.1533        0.0
# Q3 2021          -6.7612        -7.8416       -3.7672        0.0
# Q4 2021          -7.5916       -26.6704       -6.3461        0.0
# Q1 2022         -24.9287       -32.5605      -11.1835        0.0
# Q2 2022         -24.7596       -45.1098      -16.7038        0.0
# Q3 2022         -13.1851       -14.0784      -15.3204        0.0
# Q4 2022          -7.4610       -55.8268       -6.7677        0.0
# Q1 2023         -11.5986       -11.7330       -6.1288        0.0
# Q2 2023          -4.3668       -10.3644       -2.8843        0.0
# Q3 2023          -4.1644        -8.0718       -5.2450        0.0
# Q4 2023          -7.8197        -7.5809       -5.0849        0.0
# Q1 2024          -4.3540        -6.2293       -1.3138        0.0
# Q2 2024          -9.9278       -11.7461       -3.6294        0.0
# Q3 2024         -13.1173       -22.6860       -6.7105        0.0
# Q4 2024         -10.7971       -13.1404       -3.5657        0.0
# Q1 2025         -22.7166       -18.0505       -8.1048        0.0
# Q2 2025         -10.8090       -14.9956      -11.4429        0.0
# Q3 2025          -2.1390        -3.5160       -0.8845        0.0
#
# Max Drawdown Duration (days)
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020               29             29            29          0
# Q2 2020               15             12            16          0
# Q3 2020               26             19            19          0
# Q4 2020               32             24            19          0
# Q1 2021               46             45            10          0
# Q2 2021               55             55            10          0
# Q3 2021               17             22            19          0
# Q4 2021               22             39            37          0
# Q1 2022               60             60            60          0
# Q2 2022               60             60            60          0
# Q3 2022               44             33            32          0
# Q4 2022               25             61            21          0
# Q1 2023               45             32            30          0
# Q2 2023               12             36            20          0
# Q3 2023               21             20            43          0
# Q4 2023               27             50            12          0
# Q1 2024                7             15             5          0
# Q2 2024               23             16            18          0
# Q3 2024               21             57            22          0
# Q4 2024               18             48            16          0
# Q1 2025               29             29            29          0
# Q2 2025               26              8            20          0
# Q3 2025                7              5            12          0
#
# Sharpe Ratio
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020          -0.0127        -0.7442       -1.0783        NaN
# Q2 2020           3.3279         3.2887        2.9196        NaN
# Q3 2020          -0.0011         1.7547        2.0828        NaN
# Q4 2020           2.0874         2.7089        3.7005        NaN
# Q1 2021          -0.2020        -0.6147        2.4480        NaN
# Q2 2021           0.3418         0.9062        3.1101        NaN
# Q3 2021           1.7843         1.9035        0.0349        NaN
# Q4 2021           3.4144         2.3111        2.0296        NaN
# Q1 2022          -0.6882        -0.3859       -0.5609        NaN
# Q2 2022          -2.0730        -2.2604       -2.1147        NaN
# Q3 2022           0.1003         1.4593       -1.3759        NaN
# Q4 2022           1.1099        -3.7309        1.6103        NaN
# Q1 2023           0.1427         3.4228        2.8266        NaN
# Q2 2023           2.8594         2.6019        3.1497        NaN
# Q3 2023           1.8121         1.5916       -0.6361        NaN
# Q4 2023           2.1425        -0.4231        3.7174        NaN
# Q1 2024           6.9622         5.5006        5.6592        NaN
# Q2 2024           2.0167         3.0618        1.9746        NaN
# Q3 2024           2.3461         0.0541        2.2368        NaN
# Q4 2024          -0.2182        -0.1731        1.4856        NaN
# Q1 2025           0.6000        -0.9562        0.5770        NaN
# Q2 2025           1.6935         2.7714        1.5944        NaN
# Q3 2025           2.7502        10.6014        3.9703        NaN
#
# Sortino Ratio
# ----------------------------------------
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020          -0.0173        -1.0138       -1.3523        NaN
# Q2 2020           5.1884         4.9506        4.2166        NaN
# Q3 2020          -0.0017         2.3845        2.7999        NaN
# Q4 2020           2.4752         3.9647        5.5081        NaN
# Q1 2021          -0.3601        -1.1336        3.1296        NaN
# Q2 2021           0.5203         1.5140        4.5145        NaN
# Q3 2021           2.7201         3.1596        0.0475        NaN
# Q4 2021           5.4963         3.2444        2.8978        NaN
# Q1 2022          -1.4081        -0.6743       -1.0638        NaN
# Q2 2022          -3.3099        -3.1852       -3.1201        NaN
# Q3 2022           0.1798         2.2629       -2.0696        NaN
# Q4 2022           2.1903        -5.4067        3.2840        NaN
# Q1 2023           0.2226         5.5002        4.9707        NaN
# Q2 2023           6.1610         4.0525        6.6940        NaN
# Q3 2023           3.5717         2.7576       -0.8746        NaN
# Q4 2023           4.2194        -0.7632        5.7021        NaN
# Q1 2024          12.4667         9.2041       10.4107        NaN
# Q2 2024           3.3151         4.7117        3.0505        NaN
# Q3 2024           3.7100         0.0918        2.9569        NaN
# Q4 2024          -0.3320        -0.2549        1.9689        NaN
# Q1 2025           0.9383        -1.1820        0.8222        NaN
# Q2 2025           2.2073         3.4197        1.8681        NaN
# Q3 2025           7.2568        17.2780        7.1891        NaN

# %%
# --- เริ่มโค้ดสำหรับบันทึก Excel ---
qoq_excel_path = f"{output_dir}/{train_type}/02_Quarterly_{model_type}_{pe_type}_{pre_post}_run_{run_no}.xlsx"

for metric in all_metrics:
    sheet_name = metric.replace(" ", "_")
    df_to_save = quarterly_comparison[metric].round(4)
    save_dataframe_to_new_sheet(df_to_save, qoq_excel_path, sheet_name)
# Out:
# DataFrame saved to sheet 'Total_Return_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Annualized_Return_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Volatility_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Max_Drawdown_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Max_Drawdown_Duration_(days)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Sharpe_Ratio' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Sortino_Ratio' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/02_Quarterly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %%
# Plotting
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=('Quarterly Returns (%)', 'Quarterly Volatility (%)', 
                   'Quarterly Sharpe Ratio', 'Quarterly Max Drawdown (%)'),
    vertical_spacing=0.2,
    horizontal_spacing=0.2
)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
quarters = list(quarterly_comparison['Total Return (%)'].index)

# Plot quarterly returns
for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=quarters,
            y=quarterly_comparison['Total Return (%)'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=True
        ),
        row=1, col=1
    )

for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=quarters,
            y=quarterly_comparison['Volatility (%)'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=False
        ),
        row=1, col=2
    )

for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=quarters,
            y=quarterly_comparison['Sharpe Ratio'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=False
        ),
        row=2, col=1
    )

for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=quarters,
            y=quarterly_comparison['Max Drawdown (%)'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=False
        ),
        row=2, col=2
    )

fig.update_layout(
    title='Quarterly Portfolio Performance Comparison',
    height=700,
    showlegend=True,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

# Update axes labels
fig.update_yaxes(title_text="Return (%)", row=1, col=1)
fig.update_yaxes(title_text="Volatility (%)", row=1, col=2)
fig.update_yaxes(title_text="Sharpe Ratio", row=2, col=1)
fig.update_yaxes(title_text="Max Drawdown (%)", row=2, col=2)

fig.show()

# Summary Statistics by Quarter
print("\n" + "="*60)
print("QUARTERLY PERFORMANCE SUMMARY")
print("="*60)

for quarter in quarters:
    print(f"\n{quarter}:")
    print("-" * 20)
    
    # Best performing portfolio this quarter
    quarter_returns = quarterly_comparison['Total Return (%)'].loc[quarter]
    best_return = quarter_returns.idxmax()
    print(f"Best Return: {best_return} ({quarter_returns[best_return]:.2f}%)")
    
    # Best Sharpe ratio this quarter
    quarter_sharpe = quarterly_comparison['Sharpe Ratio'].loc[quarter].dropna()
    if not quarter_sharpe.empty:
        best_sharpe = quarter_sharpe.idxmax()
        print(f"Best Sharpe: {best_sharpe} ({quarter_sharpe[best_sharpe]:.3f})")
    
    # Lowest volatility this quarter
    quarter_vol = quarterly_comparison['Volatility (%)'].loc[quarter].dropna()
    if not quarter_vol.empty:
        lowest_vol = quarter_vol.idxmin()
        print(f"Lowest Vol: {lowest_vol} ({quarter_vol[lowest_vol]:.2f}%)")

# Ranking Analysis
print("\n" + "="*60)
print("PORTFOLIO RANKINGS BY QUARTER")
print("="*60)

ranking_df = pd.DataFrame(index=quarters, columns=portfolios.keys())

for quarter in quarters:
    # Rank by quarterly returns (1 = best)
    quarter_returns = quarterly_comparison['Total Return (%)'].loc[quarter]
    ranks = quarter_returns.rank(ascending=False, method='min')
    ranking_df.loc[quarter] = ranks

print("\nRanking by Quarterly Returns (1=Best, 4=Worst):")
print(ranking_df.astype(int))

# Average ranking
avg_ranking = ranking_df.mean().sort_values()
print(f"\nAverage Ranking Across All Quarters:")
print("-" * 40)
for portfolio, avg_rank in avg_ranking.items():
    print(f"{portfolio}: {avg_rank:.2f}")

# Win rate analysis
print(f"\nQuarterly Win Rate (% of quarters ranked #1):")
print("-" * 45)
for portfolio in portfolios.keys():
    win_rate = (ranking_df[portfolio] == 1).sum() / len(quarters) * 100
    print(f"{portfolio}: {win_rate:.1f}%")

# Save the plot to a file
fig.write_html(f'{output_dir}/{train_type}/QoQ_performance_{model_type}_run_{run_no}.html')
fig.write_image(f'{output_dir}/{train_type}/QoQ_performance_{model_type}_run_{run_no}.png')
# Out:
# ============================================================
# QUARTERLY PERFORMANCE SUMMARY
# ============================================================
#
# Q1 2020:
# --------------------
# Best Return: Benchmark (0.00%)
# Best Sharpe: Model Portfolio (-0.013)
# Lowest Vol: Benchmark (0.00%)
#
# Q2 2020:
# --------------------
# Best Return: MVO Portfolio (30.67%)
# Best Sharpe: Model Portfolio (3.328)
# Lowest Vol: Benchmark (0.00%)
#
# Q3 2020:
# --------------------
# Best Return: MVO Portfolio (15.89%)
# Best Sharpe: Equal Weight (2.083)
# Lowest Vol: Benchmark (0.00%)
#
# Q4 2020:
# --------------------
# Best Return: MVO Portfolio (27.39%)
# Best Sharpe: Equal Weight (3.700)
# Lowest Vol: Benchmark (0.00%)
#
# Q1 2021:
# --------------------
# Best Return: Equal Weight (8.92%)
# Best Sharpe: Equal Weight (2.448)
# Lowest Vol: Benchmark (0.00%)
#
# Q2 2021:
# --------------------
# Best Return: Equal Weight (8.40%)
# Best Sharpe: Equal Weight (3.110)
# Lowest Vol: Benchmark (0.00%)
#
# Q3 2021:
# --------------------
# Best Return: MVO Portfolio (13.45%)
# Best Sharpe: MVO Portfolio (1.904)
# Lowest Vol: Benchmark (0.00%)
#
# Q4 2021:
# --------------------
# Best Return: MVO Portfolio (36.06%)
# Best Sharpe: Model Portfolio (3.414)
# Lowest Vol: Benchmark (0.00%)
#
# Q1 2022:
# --------------------
# Best Return: Benchmark (0.00%)
# Best Sharpe: MVO Portfolio (-0.386)
# Lowest Vol: Benchmark (0.00%)
#
# Q2 2022:
# --------------------
# Best Return: Benchmark (0.00%)
# Best Sharpe: Model Portfolio (-2.073)
# Lowest Vol: Benchmark (0.00%)
#
# Q3 2022:
# --------------------
# Best Return: MVO Portfolio (16.57%)
# Best Sharpe: MVO Portfolio (1.459)
# Lowest Vol: Benchmark (0.00%)
#
# Q4 2022:
# --------------------
# Best Return: Equal Weight (9.40%)
# Best Sharpe: Equal Weight (1.610)
# Lowest Vol: Benchmark (0.00%)
#
# Q1 2023:
# --------------------
# Best Return: MVO Portfolio (21.78%)
# Best Sharpe: MVO Portfolio (3.423)
# Lowest Vol: Benchmark (0.00%)
#
# Q2 2023:
# --------------------
# Best Return: MVO Portfolio (17.02%)
# Best Sharpe: Equal Weight (3.150)
# Lowest Vol: Benchmark (0.00%)
#
# Q3 2023:
# --------------------
# Best Return: MVO Portfolio (8.92%)
# Best Sharpe: Model Portfolio (1.812)
# Lowest Vol: Benchmark (0.00%)
#
# Q4 2023:
# --------------------
# Best Return: Equal Weight (11.77%)
# Best Sharpe: Equal Weight (3.717)
# Lowest Vol: Benchmark (0.00%)
#
# Q1 2024:
# --------------------
# Best Return: Model Portfolio (44.45%)
# Best Sharpe: Model Portfolio (6.962)
# Lowest Vol: Benchmark (0.00%)
#
# Q2 2024:
# --------------------
# Best Return: MVO Portfolio (31.08%)
# Best Sharpe: MVO Portfolio (3.062)
# Lowest Vol: Benchmark (0.00%)
#
# Q3 2024:
# --------------------
# Best Return: Model Portfolio (22.14%)
# Best Sharpe: Model Portfolio (2.346)
# Lowest Vol: Benchmark (0.00%)
#
# Q4 2024:
# --------------------
# Best Return: Equal Weight (4.48%)
# Best Sharpe: Equal Weight (1.486)
# Lowest Vol: Benchmark (0.00%)
#
# Q1 2025:
# --------------------
# Best Return: Model Portfolio (4.64%)
# Best Sharpe: Model Portfolio (0.600)
# Lowest Vol: Benchmark (0.00%)
#
# Q2 2025:
# --------------------
# Best Return: MVO Portfolio (36.02%)
# Best Sharpe: MVO Portfolio (2.771)
# Lowest Vol: Benchmark (0.00%)
#
# Q3 2025:
# --------------------
# Best Return: MVO Portfolio (16.48%)
# Best Sharpe: MVO Portfolio (10.601)
# Lowest Vol: Benchmark (0.00%)
#
# ============================================================
# PORTFOLIO RANKINGS BY QUARTER
# ============================================================
#
# Ranking by Quarterly Returns (1=Best, 4=Worst):
#          Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# Q1 2020                2              4             3          1
# Q2 2020                2              1             3          4
# Q3 2020                4              1             2          3
# Q4 2020                3              1             2          4
# Q1 2021                3              4             1          2
# Q2 2021                3              2             1          4
# Q3 2021                2              1             3          4
# Q4 2021                2              1             3          4
# Q1 2022                3              4             2          1
# Q2 2022                3              4             2          1
# Q3 2022                2              1             4          3
# Q4 2022                2              4             1          3
# Q1 2023                3              1             2          4
# Q2 2023                2              1             3          4
# Q3 2023                2              1             4          3
# Q4 2023                2              4             1          3
# Q1 2024                1              2             3          4
# Q2 2024                2              1             3          4
# Q3 2024                1              4             2          3
# Q4 2024                3              4             1          2
# Q1 2025                1              4             2          3
# Q2 2025                2              1             3          4
# Q3 2025                2              1             3          4
#
# Average Ranking Across All Quarters:
# ----------------------------------------
# Model Portfolio: 2.26
# MVO Portfolio: 2.26
# Equal Weight: 2.35
# Benchmark: 3.13
#
# Quarterly Win Rate (% of quarters ranked #1):
# ---------------------------------------------
# Model Portfolio: 13.0%
# MVO Portfolio: 52.2%
# Equal Weight: 21.7%
# Benchmark: 13.0%

# %% [markdown]
# ### Yearly Comparison

# %%
# Main Analysis
print("Yearly Performance Analysis")
print("=" * 50)

# Get yearly periods
yearly_periods = get_yearly_periods(rebalance_dates, data)

# Portfolio definitions
portfolios = {
    'Model Portfolio': model_weights_df,
    'MVO Portfolio': mvo_weights_df,
    'Equal Weight': equal_weights_df,
    'Benchmark': benchmark_df
}

# Calculate yearly performance for each portfolio
yearly_results = {}
weights_df_2 = weights_df.copy()
for portfolio_name, weights_df_2 in portfolios.items():
    yearly_results[portfolio_name] = {}
    
    for period in yearly_periods:
        year = period['year']
        returns = calculate_yearly_portfolio_returns(data, weights_df_2, period, rebalance_dates)
        metrics = calculate_yearly_metrics(returns)
        yearly_results[portfolio_name][year] = metrics

# Create comprehensive results DataFrame
all_metrics = ['Total Return (%)', 'Annualized Return (%)', 'Volatility (%)', 
               'Sharpe Ratio', 'Sortino Ratio', 'Max Drawdown (%)', 
               'Max DD Duration (days)', 'VaR 95% (%)', 'Calmar Ratio', 'Trading Days']

yearly_comparison = {}

for metric in all_metrics:
    yearly_comparison[metric] = pd.DataFrame({
        portfolio: {year: yearly_results[portfolio][year][metric] 
                   for year in yearly_results[portfolio]}
        for portfolio in portfolios.keys()
    })

# Display results
for metric in all_metrics:
    print(f"\n{metric}")
    print("-" * 40)
    if metric in ['Trading Days']:
        print(yearly_comparison[metric].astype(int))
    else:
        print(yearly_comparison[metric].round(3))
# Out:
# Yearly Performance Analysis
# ==================================================
#
# Total Return (%)
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020           38.238         61.999        26.086        0.0
# 2021           25.677         48.206        30.423        0.0
# 2022          -21.818        -68.851       -11.361        0.0
# 2023           43.294         51.288        34.844        0.0
# 2024           98.439         79.721        35.981        0.0
# 2025           26.270         37.704        15.950        0.0
#
# Annualized Return (%)
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020           38.238         61.999        26.086        0.0
# 2021           25.792         48.438        30.561        0.0
# 2022          -21.972        -69.140       -11.447        0.0
# 2023           43.916         52.044        35.330        0.0
# 2024           98.981         80.141        36.148        0.0
# 2025           52.633         78.609        30.774        0.0
#
# Volatility (%)
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020           38.789         46.904        32.850        0.0
# 2021           30.311         46.527        12.197        0.0
# 2022           37.229         64.560        22.992        0.0
# 2023           19.863         22.513        12.338        0.0
# 2024           28.231         35.384        11.129        0.0
# 2025           42.578         43.677        20.775        0.0
#
# Sharpe Ratio
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020            0.977          1.221         0.810        NaN
# 2021            0.841          1.037         2.084        NaN
# 2022           -0.534         -1.523        -0.501        NaN
# 2023            1.832          1.886         2.353        NaN
# 2024            2.510          1.784         2.650        NaN
# 2025            1.159          1.502         1.298        NaN
#
# Sortino Ratio
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020            1.279          1.586         0.922        NaN
# 2021            1.225          1.586         2.845        NaN
# 2022           -0.863         -2.219        -0.811        NaN
# 2023            3.303          3.139         3.838        NaN
# 2024            3.942          2.755         3.703        NaN
# 2025            1.585          1.876         1.592        NaN
#
# Max Drawdown (%)
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020          -24.958        -38.014       -30.855        0.0
# 2021          -28.844        -30.071        -6.346        0.0
# 2022          -28.554        -71.221       -21.418        0.0
# 2023          -11.599        -11.733        -8.007        0.0
# 2024          -13.117        -22.686        -6.710        0.0
# 2025          -27.545        -29.443       -16.496        0.0
#
# Max DD Duration (days)
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020               74            111           106          0
# 2021              194            179            37          0
# 2022              249            249           249          0
# 2023               63             83            74          0
# 2024               23             65            25          0
# 2025              109             58            71          0
#
# VaR 95% (%)
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020           -3.446         -4.807        -3.136        0.0
# 2021           -2.805         -4.348        -1.133        0.0
# 2022           -3.891         -7.106        -2.537        0.0
# 2023           -1.772         -2.052        -1.302        0.0
# 2024           -2.850         -3.374        -1.097        0.0
# 2025           -4.492         -4.474        -1.699        0.0
#
# Calmar Ratio
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020            1.532          1.631         0.845        NaN
# 2021            0.894          1.611         4.816        NaN
# 2022           -0.769         -0.971        -0.534        NaN
# 2023            3.786          4.436         4.413        NaN
# 2024            7.546          3.533         5.387        NaN
# 2025            1.911          2.670         1.866        NaN
#
# Trading Days
# ----------------------------------------
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020              252            252           252        252
# 2021              251            251           251        251
# 2022              250            250           250        250
# 2023              249            249           249        249
# 2024              251            251           251        251
# 2025              139            139           139        139

# %%
# Plotting
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=('Annual Returns (%)', 'Annual Volatility (%)', 
                   'Annual Sharpe Ratio', 'Annual Max Drawdown (%)'),
                   #'Annual Sortino Ratio', 'Annual Calmar Ratio'),
    vertical_spacing=0.12,
    horizontal_spacing=0.1
)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
years = list(yearly_comparison['Total Return (%)'].index)

# Plot annual returns
for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=years,
            y=yearly_comparison['Total Return (%)'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=True
        ),
        row=1, col=1
    )

# Plot annual volatility
for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=years,
            y=yearly_comparison['Volatility (%)'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=False
        ),
        row=1, col=2
    )

# Plot annual Sharpe ratio
for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=years,
            y=yearly_comparison['Sharpe Ratio'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=False
        ),
        row=2, col=1
    )

# Plot annual max drawdown
for i, portfolio in enumerate(portfolios.keys()):
    fig.add_trace(
        go.Bar(
            x=years,
            y=yearly_comparison['Max Drawdown (%)'][portfolio],
            name=portfolio,
            marker_color=colors[i],
            showlegend=False
        ),
        row=2, col=2
    )

# # Plot annual Sortino ratio
# for i, portfolio in enumerate(portfolios.keys()):
#     fig.add_trace(
#         go.Scatter(
#             x=years,
#             y=yearly_comparison['Sortino Ratio'][portfolio],
#             mode='lines+markers',
#             name=portfolio,
#             line=dict(color=colors[i]),
#             showlegend=False
#         ),
#         row=3, col=1
#     )

# # Plot annual Calmar ratio
# for i, portfolio in enumerate(portfolios.keys()):
#     fig.add_trace(
#         go.Scatter(
#             x=years,
#             y=yearly_comparison['Calmar Ratio'][portfolio],
#             mode='lines+markers',
#             name=portfolio,
#             line=dict(color=colors[i]),
#             showlegend=False
#         ),
#         row=3, col=2
#     )

# Update layout
fig.update_layout(
    title='Annual Portfolio Performance Comparison',
    height=900,
    showlegend=True,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

# Update axes labels
fig.update_yaxes(title_text="Return (%)", row=1, col=1)
fig.update_yaxes(title_text="Volatility (%)", row=1, col=2)
fig.update_yaxes(title_text="Sharpe Ratio", row=2, col=1)
fig.update_yaxes(title_text="Max Drawdown (%)", row=2, col=2)
# fig.update_yaxes(title_text="Sortino Ratio", row=3, col=1)
# fig.update_yaxes(title_text="Calmar Ratio", row=3, col=2)

fig.show()

# Save the plot to a file
fig.write_html(f'{output_dir}/{train_type}/YoY_performance_{model_type}_run_{run_no}.html')
fig.write_image(f'{output_dir}/{train_type}/YoY_performance_{model_type}_run_{run_no}.png')

# %%
# Summary Statistics by Year
print("\n" + "="*60)
print("ANNUAL PERFORMANCE SUMMARY")
print("="*60)

for year in years:
    print(f"\n{year}:")
    print("-" * 20)
    
    # Best performing portfolio this year
    year_returns = yearly_comparison['Total Return (%)'].loc[year]
    best_return = year_returns.idxmax()
    print(f"Best Return: {best_return} ({year_returns[best_return]:.2f}%)")
    
    # Best Sharpe ratio this year
    year_sharpe = yearly_comparison['Sharpe Ratio'].loc[year].dropna()
    if not year_sharpe.empty:
        best_sharpe = year_sharpe.idxmax()
        print(f"Best Sharpe: {best_sharpe} ({year_sharpe[best_sharpe]:.3f})")
    
    # Lowest volatility this year
    year_vol = yearly_comparison['Volatility (%)'].loc[year].dropna()
    if not year_vol.empty:
        lowest_vol = year_vol.idxmin()
        print(f"Lowest Vol: {lowest_vol} ({year_vol[lowest_vol]:.2f}%)")
    
    # Best Calmar ratio this year
    year_calmar = yearly_comparison['Calmar Ratio'].loc[year].dropna()
    if not year_calmar.empty:
        best_calmar = year_calmar.idxmax()
        print(f"Best Calmar: {best_calmar} ({year_calmar[best_calmar]:.3f})")

# Ranking Analysis
print("\n" + "="*60)
print("PORTFOLIO RANKINGS BY YEAR")
print("="*60)

ranking_df = pd.DataFrame(index=years, columns=portfolios.keys())

for year in years:
    # Rank by annual returns (1 = best)
    year_returns = yearly_comparison['Total Return (%)'].loc[year]
    ranks = year_returns.rank(ascending=False, method='min')
    ranking_df.loc[year] = ranks

print("\nRanking by Annual Returns (1=Best, 4=Worst):")
print(ranking_df.astype(int))

# Average ranking
avg_ranking = ranking_df.mean().sort_values()
print(f"\nAverage Ranking Across All Years:")
print("-" * 40)
for portfolio, avg_rank in avg_ranking.items():
    print(f"{portfolio}: {avg_rank:.2f}")

# Win rate analysis
print(f"\nAnnual Win Rate (% of years ranked #1):")
print("-" * 45)
for portfolio in portfolios.keys():
    win_rate = (ranking_df[portfolio] == 1).sum() / len(years) * 100
    print(f"{portfolio}: {win_rate:.1f}%")

# Multi-year consistency analysis
print(f"\nConsistency Analysis:")
print("-" * 25)
for portfolio in portfolios.keys():
    returns_series = yearly_comparison['Total Return (%)'][portfolio].dropna()
    if len(returns_series) > 1:
        consistency = returns_series.std()
        print(f"{portfolio} - Return Std Dev: {consistency:.2f}%")

# Best and worst years
print(f"\nBest and Worst Years:")
print("-" * 25)
for portfolio in portfolios.keys():
    returns_series = yearly_comparison['Total Return (%)'][portfolio].dropna()
    if len(returns_series) > 0:
        best_year = returns_series.idxmax()
        worst_year = returns_series.idxmin()
        print(f"{portfolio}:")
        print(f"  Best: {best_year} ({returns_series[best_year]:.2f}%)")
        print(f"  Worst: {worst_year} ({returns_series[worst_year]:.2f}%)")
# Out:
# ============================================================
# ANNUAL PERFORMANCE SUMMARY
# ============================================================
#
# 2020:
# --------------------
# Best Return: MVO Portfolio (62.00%)
# Best Sharpe: MVO Portfolio (1.221)
# Lowest Vol: Benchmark (0.00%)
# Best Calmar: MVO Portfolio (1.631)
#
# 2021:
# --------------------
# Best Return: MVO Portfolio (48.21%)
# Best Sharpe: Equal Weight (2.084)
# Lowest Vol: Benchmark (0.00%)
# Best Calmar: Equal Weight (4.816)
#
# 2022:
# --------------------
# Best Return: Benchmark (0.00%)
# Best Sharpe: Equal Weight (-0.501)
# Lowest Vol: Benchmark (0.00%)
# Best Calmar: Equal Weight (-0.534)
#
# 2023:
# --------------------
# Best Return: MVO Portfolio (51.29%)
# Best Sharpe: Equal Weight (2.353)
# Lowest Vol: Benchmark (0.00%)
# Best Calmar: MVO Portfolio (4.436)
#
# 2024:
# --------------------
# Best Return: Model Portfolio (98.44%)
# Best Sharpe: Equal Weight (2.650)
# Lowest Vol: Benchmark (0.00%)
# Best Calmar: Model Portfolio (7.546)
#
# 2025:
# --------------------
# Best Return: MVO Portfolio (37.70%)
# Best Sharpe: MVO Portfolio (1.502)
# Lowest Vol: Benchmark (0.00%)
# Best Calmar: MVO Portfolio (2.670)
#
# ============================================================
# PORTFOLIO RANKINGS BY YEAR
# ============================================================
#
# Ranking by Annual Returns (1=Best, 4=Worst):
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020                2              1             3          4
# 2021                3              1             2          4
# 2022                3              4             2          1
# 2023                2              1             3          4
# 2024                1              2             3          4
# 2025                2              1             3          4
#
# Average Ranking Across All Years:
# ----------------------------------------
# MVO Portfolio: 1.67
# Model Portfolio: 2.17
# Equal Weight: 2.67
# Benchmark: 3.50
#
# Annual Win Rate (% of years ranked #1):
# ---------------------------------------------
# Model Portfolio: 16.7%
# MVO Portfolio: 66.7%
# Equal Weight: 0.0%
# Benchmark: 16.7%
#
# Consistency Analysis:
# -------------------------
# Model Portfolio - Return Std Dev: 38.72%
# MVO Portfolio - Return Std Dev: 52.84%
# Equal Weight - Return Std Dev: 17.88%
# Benchmark - Return Std Dev: 0.00%
#
# Best and Worst Years:
# -------------------------
# Model Portfolio:
#   Best: 2024 (98.44%)
#   Worst: 2022 (-21.82%)
# MVO Portfolio:
#   Best: 2024 (79.72%)
#   Worst: 2022 (-68.85%)
# Equal Weight:
#   Best: 2024 (35.98%)
#   Worst: 2022 (-11.36%)
# Benchmark:
#   Best: 2020 (0.00%)
#   Worst: 2020 (0.00%)

# %%
# --- เริ่มโค้ดสำหรับบันทึก Excel ---
output_excel_path = f"{output_dir}/{train_type}/03_Yearly_{model_type}_{pe_type}_{pre_post}_run_{run_no}.xlsx"

for metric in all_metrics:
    sheet_name = metric.replace(" ", "_")
    df_to_save = yearly_comparison[metric].round(4)
    save_dataframe_to_new_sheet(df_to_save, output_excel_path, sheet_name)
# Out:
# DataFrame saved to sheet 'Total_Return_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Annualized_Return_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Volatility_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Sharpe_Ratio' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Sortino_Ratio' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Max_Drawdown_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Max_DD_Duration_(days)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'VaR_95%_(%)' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Calmar_Ratio' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄
# DataFrame saved to sheet 'Trading_Days' in existing file: Results_NoCons/01_2_Transformer_tAPE_PostNorm_temp_1.0/03_Yearly_Transformer_tAPE_PostNorm_run_12_maximize_return.xlsx 📄

# %%
yearly_comparison['Sortino Ratio']
# Out:
#       Model Portfolio  MVO Portfolio  Equal Weight  Benchmark
# 2020         1.278760       1.585928      0.921801        NaN
# 2021         1.225154       1.585651      2.844717        NaN
# 2022        -0.862957      -2.218909     -0.810560        NaN
# 2023         3.303245       3.138793      3.838259        NaN
# 2024         3.941693       2.754783      3.702616        NaN
# 2025         1.585499       1.876483      1.591957        NaN

# %%
os.system('say "All code has finished"')
# Out:
# 0
